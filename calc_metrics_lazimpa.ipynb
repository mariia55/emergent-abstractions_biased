# %%
import pickle
from utils.analysis_from_interaction import *
from egg.core.language_analysis import Disent
from language_analysis_local import TopographicSimilarityConceptLevel, encode_target_concepts_for_topsim
from utils.analysis_tools_lazimpa import *

# %% [markdown]
# # calculate metrics from stored interactions

# %%
datasets = ('(3,4)', '(3,8)', '(4,4)')
n_attributes = (3, 3, 4)
n_values = (4, 8, 4)
n_epochs = 300
paths = ['results/' + d + '_game_size_10_vsf_3/' for d in datasets]

# %%
datasets = ('(4,4)',)
n_attributes = (4,)
n_values = (4,)
n_epochs = 100
paths = ['results/' + d + '_game_size_10_vsf_3/' for d in datasets]

# %%
datasets = ['(3,4)',]
n_values = [4,]
n_attributes = [3,]
n_epochs = 300
paths = ['results/' + d + '_game_size_10_vsf_3/' for d in datasets]

# %%
context_unaware = False # whether original or context_unaware simulations are evaluated
lazy = True # whether the lazy agent is used
impatient = True
setting = ""
pickle_data = False #True
if not lazy:
    start = 'impatience_' if impatient else ''
    if context_unaware:
        setting = start + 'context_unaware'
    else:
        setting = start + 'context_aware'
        if impatient == False:
            setting = 'standard'
else:
    start = 'lazimpa' if impatient else 'lazy'
    if context_unaware:
        setting = start + '_context_unaware'
    else:
        setting = start + '_context_aware'
setting
# Out:
# 'lazimpa_context_aware'

# %% [markdown]
# ## entropy scores: MI, effectiveness, efficiency

# %%
for d in range(len(datasets)):
    
    for run in range(5):

        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/' 
        interaction = load_interaction(paths[d],setting,run,n_epochs)

        attributes = n_attributes[d]
        values = n_values[d]
        scores = information_scores(interaction, attributes, values, normalizer="arithmetic")

        if pickle_data:
            pickle.dump(scores, open(path_to_run + 'entropy_scores.pkl', 'wb'))
scores
# Out:
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:315: RuntimeWarning: invalid value encountered in divide
#   (m_entropy_concept_x_context + c_entropy_concept_x_context - joint_entropy_concept_x_context)
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:324: RuntimeWarning: invalid value encountered in divide
#   normalized_effectiveness_conc_x_cont = ((joint_entropy_concept_x_context - m_entropy_concept_x_context)
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:331: RuntimeWarning: invalid value encountered in divide
#   normalized_consistency_conc_x_cont = (
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# {'normalized_mutual_info': 0.5646424659616172,
#  'normalized_mutual_info_hierarchical': array([0.9412313 , 0.71581218, 0.61050991, 0.56984363]),
#  'normalized_mutual_info_context_dep': array([0.60728343, 0.64302973, 0.69433659, 0.73332883]),
#  'normalized_mutual_info_concept_x_context': array([0.9412313 ,        nan,        nan,        nan, 0.73845603,
#         0.75726969,        nan,        nan, 0.64400332, 0.67973626,
#         0.72967362,        nan, 0.62280925, 0.65584262, 0.70397423,
#         0.73332883]),
#  'effectiveness': 0.5327886972087245,
#  'effectiveness_hierarchical': array([0.95796588, 0.7092366 , 0.60438355, 0.58895723]),
#  'effectiveness_context_dep': array([0.52052878, 0.58264702, 0.68003261, 0.7767193 ]),
#  'effectiveness_concept_x_context': array([0.95796588,        nan,        nan,        nan, 0.69333176,
#         0.75908013,        nan,        nan, 0.58151209, 0.65248153,
#         0.74343608,        nan, 0.57371813, 0.62992165, 0.72519545,
#         0.7767193 ]),
#  'consistency': 0.6005473101182175,
#  'consistency_hierarchical': array([0.92507135, 0.72251083, 0.61676173, 0.55193163]),
#  'consistency_context_dep': array([0.72873988, 0.71737498, 0.70925525, 0.69452978]),
#  'consistency_concept_x_context': array([0.92507135,        nan,        nan,        nan, 0.78986285,
#         0.75546787,        nan,        nan, 0.72154269, 0.70936714,
#         0.71641144,        nan, 0.68108762, 0.68398841, 0.68395968,
#         0.69452978])}

# %% [markdown]
# ##  message length

# %%
# we evaluated message length per hierarchy level after training but 
# you can also use the HierarchicalMessageLength callback and store the results 
# TODO: Message length results look weird, needs to be fixed!

for d in range(len(datasets)):
    
    for run in range(5):
        
        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/' 
        interaction = load_interaction(paths[d],setting,run,n_epochs)

        attributes = n_attributes[d]
        values = n_values[d]
        scores = message_length_per_hierarchy_level(interaction, attributes)
        
        if pickle_data:
            pickle.dump(scores, open(path_to_run + 'message_length_hierarchical.pkl', 'wb'))
scores
# Out:
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# message length tensor([1, 1, 1,  ..., 1, 2, 1])
# hierarchical [1.402, 1.076, 1.122]
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# message length tensor([1, 1, 1,  ..., 1, 1, 0])
# hierarchical [1.465, 1.296, 1.183]
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# message length tensor([0, 1, 1,  ..., 1, 1, 2])
# hierarchical [1.042, 1.08, 1.085]
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# message length tensor([1, 2, 1,  ..., 1, 0, 1])
# hierarchical [1.036, 1.077, 1.03]
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# message length tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [1.441, 1.197, 1.203]
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# message length tensor([1, 2, 2,  ..., 2, 2, 2])
# hierarchical [1.8, 1.542, 1.467]
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# message length tensor([2, 0, 2,  ..., 2, 2, 1])
# hierarchical [1.741, 1.285, 1.376]
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# message length tensor([2, 1, 2,  ..., 2, 2, 2])
# hierarchical [1.88, 1.709, 1.681]
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# message length tensor([1, 0, 1,  ..., 1, 2, 1])
# hierarchical [2.261, 1.724, 1.414]
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# message length tensor([1, 1, 1,  ..., 1, 1, 2])
# hierarchical [1.584, 1.344, 1.338]
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# message length tensor([0, 0, 0,  ..., 1, 1, 1])
# hierarchical [0.808, 0.988, 1.055, 1.083]
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# message length tensor([1, 1, 2,  ..., 2, 2, 2])
# hierarchical [1.084, 1.142, 1.084, 1.078]
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# message length tensor([0, 1, 1,  ..., 2, 2, 1])
# hierarchical [1.01, 1.134, 1.169, 1.215]
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# message length tensor([1, 1, 1,  ..., 1, 1, 0])
# hierarchical [1.022, 1.017, 1.062, 1.095]
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# message length tensor([1, 1, 1,  ..., 1, 1, 2])
# hierarchical [0.895, 1.011, 1.046, 1.065]
# [0.895, 1.011, 1.046, 1.065]

# %% [markdown]
# ##  symbol redundancy

# %%
for d in range(len(datasets)):
    
    attributes = n_attributes[d]
    values = n_values[d]
    vs_factor = int(paths[d][-2])
    vocab_size = (n_values[d] + 1) * vs_factor + 1
    
    for run in range(5):
        
        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/'
        #symbol_f = np.load(path_to_run + 'symbols_pernsame.npy')
        interaction = load_interaction(paths[d],setting,run,n_epochs)
        redundancy, MI = symbol_frequency(interaction, attributes, values, vocab_size)
        
        scores = {'symbol_redundancy': redundancy, 'MI_symbol-attribute_value': MI}
        
        if pickle_data:
            pickle.dump(scores, open(path_to_run + 'symbol_redundancy.pkl', 'wb'))
# Out:
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# d:\Documents\GitHub\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information

# %% [markdown]
# ## ZLA significance scores

# %%
for d in range(len(datasets)):
    
    
    for run in range(5):

        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/' 
        interaction = load_interaction(paths[d],setting,run,n_epochs)

        scores = ZLA_significance_score(interaction,num_permutations=1000,remove_after_eos=True)

        if pickle_data:
            pickle.dump(scores, open(path_to_run + 'ZLA_significance.pkl', 'wb'))
scores
# Out:
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# {'mean_message_length': tensor(2.0389),
#  'mean_weighted_message_length': tensor(1.0512),
#  'p_zla': tensor(0.)}

# %%
for d in range(len(datasets)):
    
    
    for run in range(5):

        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/' 
        interaction = load_interaction(paths[d],setting,run,n_epochs)

        scores = ZLA_significance_score(interaction,num_permutations=10000,remove_after_eos=True)

        #if pickle_data:
            #pickle.dump(scores, open(path_to_run + 'ZLA_significance.pkl', 'wb'))
        print(scores)
# Out:
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  109
# [tensor(1.9518), tensor(1.9041), tensor(1.8871), tensor(1.7599), tensor(1.8383), tensor(1.9211), tensor(1.9540), tensor(1.9024), tensor(1.9665), tensor(1.9955), tensor(1.8320), tensor(1.8326), tensor(1.9251), tensor(1.9387), tensor(1.9574), tensor(1.8400), tensor(1.8331), tensor(2.0318), tensor(1.8496), tensor(2.0284), tensor(1.8110), tensor(1.9325), tensor(1.7230), tensor(1.8848), tensor(1.8785), tensor(1.9489), tensor(2.0460), tensor(1.8065), tensor(2.0851), tensor(2.0114), tensor(2.0358), tensor(1.8541), tensor(2.0868), tensor(1.8825), tensor(1.8541), tensor(1.7418), tensor(1.8082), tensor(1.9126), tensor(1.8984), tensor(1.9716), tensor(2.0931), tensor(1.9955), tensor(1.9257), tensor(1.9535), tensor(1.8956), tensor(1.8292), tensor(1.9359), tensor(2.0221), tensor(1.9705), tensor(1.9767), tensor(1.7236), tensor(1.9325), tensor(1.8774), tensor(1.9654), tensor(1.8712), tensor(1.9245), tensor(2.0023), tensor(1.9370), tensor(1.8536), tensor(1.8950), tensor(1.9098), tensor(1.8422), tensor(1.7719), tensor(2.0335), tensor(1.9642), tensor(2.0045), tensor(1.9784), tensor(1.8048), tensor(1.9183), tensor(1.9120), tensor(1.9711), tensor(1.6958), tensor(1.9886), tensor(1.7179), tensor(1.8672), tensor(1.7690), tensor(1.7923), tensor(1.8655), tensor(1.9030), tensor(1.8802), tensor(2.0636), tensor(1.9813), tensor(1.9291), tensor(1.8978), tensor(1.8485), tensor(1.8973), tensor(1.8757), tensor(1.9654), tensor(2.0051), tensor(2.0289), tensor(1.9149), tensor(1.7469), tensor(1.8723), tensor(1.8689), tensor(1.9228), tensor(1.8053), tensor(2.0011), tensor(2.1078), tensor(2.0034), tensor(1.7804), tensor(1.9790), tensor(1.9472), tensor(1.9183), tensor(1.8496), tensor(2.1095), tensor(2.0471), tensor(1.9432), tensor(1.9784), tensor(2.0403), tensor(1.8524), tensor(1.9699), tensor(1.9637), tensor(1.8485), tensor(1.8825), tensor(1.7787), tensor(2.0136), tensor(1.8893), tensor(2.0119), tensor(1.8241), tensor(1.9540), tensor(1.9994), tensor(2.0176), tensor(2.0261), tensor(1.8411), tensor(1.8905), tensor(1.9762), tensor(1.9188), tensor(1.6924), tensor(2.1328), tensor(1.8627), tensor(1.8292), tensor(1.8610), tensor(1.9058), tensor(1.8774), tensor(1.8882), tensor(1.9625), tensor(1.9132), tensor(1.9926), tensor(1.8093), tensor(1.9977), tensor(1.9762), tensor(1.9211), tensor(1.8927), tensor(1.7798), tensor(1.9030), tensor(1.9330), tensor(2.0477), tensor(1.9098), tensor(2.0687), tensor(1.6782), tensor(2.0119), tensor(1.9410), tensor(1.7985), tensor(1.9699), tensor(1.7826), tensor(1.9461), tensor(1.8678), tensor(1.7622), tensor(1.7423), tensor(1.8581), tensor(1.7287), tensor(2.0045), tensor(1.8876), tensor(1.9183), tensor(2.0057), tensor(1.9052), tensor(1.8405), tensor(2.0596), tensor(1.8178), tensor(1.9756), tensor(1.8604), tensor(1.9750), tensor(1.8121), tensor(1.9012), tensor(1.8173), tensor(2.0715), tensor(1.9024), tensor(2.0636), tensor(1.9637), tensor(1.9427), tensor(1.8224), tensor(1.6782), tensor(1.8099), tensor(1.8780), tensor(1.6969), tensor(1.7514), tensor(1.8683), tensor(1.9211), tensor(1.9132), tensor(1.8808), tensor(1.9217), tensor(1.8638), tensor(1.8944), tensor(1.8740), tensor(1.7191), tensor(2.0363), tensor(1.9631), tensor(2.0443), tensor(1.8768), tensor(1.8644), tensor(1.7060), tensor(2.0182), tensor(2.1039), tensor(1.9064), tensor(1.9228), tensor(2.1890), tensor(1.8802), tensor(1.7469), tensor(1.8354), tensor(1.9432), tensor(1.9563), tensor(1.8036), tensor(1.8785), tensor(1.8201), tensor(1.9597), tensor(1.9160), tensor(1.9728), tensor(1.8950), tensor(1.8473), tensor(1.8808), tensor(2.0125), tensor(1.9682), tensor(1.8507), tensor(1.7537), tensor(2.0420), tensor(1.9313), tensor(1.7974), tensor(1.9932), tensor(1.9716), tensor(2.0199), tensor(2.0477), tensor(1.9728), tensor(2.0193), tensor(1.8513), tensor(1.6578), tensor(1.8593), tensor(1.9835), tensor(1.8167), tensor(2.0698), tensor(1.8791), tensor(1.9830), tensor(1.9030), tensor(2.0380), tensor(1.8978), tensor(2.0976), tensor(2.0369), tensor(1.8785), tensor(1.9847), tensor(1.8479), tensor(1.9234), ...
# {'mean_message_length': tensor(1.9174), 'mean_weighted_message_length': tensor(1.1198), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  98
# [tensor(1.8772), tensor(1.8873), tensor(1.9025), tensor(1.9383), tensor(1.9434), tensor(1.9041), tensor(1.8475), tensor(2.1429), tensor(1.9585), tensor(1.9703), tensor(1.9664), tensor(1.8430), tensor(2.0460), tensor(1.9927), tensor(2.0275), tensor(1.8206), tensor(1.8173), tensor(1.8335), tensor(1.7803), tensor(1.9367), tensor(2.0073), tensor(1.9535), tensor(1.6211), tensor(1.8873), tensor(2.0639), tensor(1.9344), tensor(1.9893), tensor(1.8800), tensor(1.8677), tensor(1.8526), tensor(1.8565), tensor(1.9742), tensor(2.0751), tensor(1.9630), tensor(1.8229), tensor(2.0348), tensor(2.1754), tensor(1.6855), tensor(1.9215), tensor(1.8739), tensor(1.7976), tensor(1.9737), tensor(1.9294), tensor(1.8419), tensor(1.8778), tensor(1.7803), tensor(2.0101), tensor(1.9955), tensor(1.9703), tensor(1.8442), tensor(2.0392), tensor(1.9922), tensor(1.8963), tensor(1.7948), tensor(1.9215), tensor(1.8509), tensor(2.0824), tensor(2.0611), tensor(1.8548), tensor(2.0263), tensor(1.9563), tensor(1.7820), tensor(1.9456), tensor(1.8615), tensor(1.8425), tensor(1.9652), tensor(2.0135), tensor(1.9058), tensor(1.8862), tensor(2.0807), tensor(1.9277), tensor(1.9226), tensor(2.0129), tensor(1.9501), tensor(1.8660), tensor(1.7382), tensor(1.9608), tensor(2.1844), tensor(1.8520), tensor(1.9580), tensor(1.8133), tensor(1.9624), tensor(1.8941), tensor(2.0645), tensor(1.7864), tensor(2.1256), tensor(2.0252), tensor(1.9759), tensor(2.0235), tensor(1.7954), tensor(1.8862), tensor(2.0538), tensor(1.8285), tensor(1.9636), tensor(1.8604), tensor(1.8750), tensor(1.8038), tensor(1.9563), tensor(1.8604), tensor(1.9490), tensor(1.8890), tensor(1.9277), tensor(1.7354), tensor(2.0510), tensor(1.8380), tensor(1.8896), tensor(1.9535), tensor(1.8621), tensor(1.7108), tensor(1.8952), tensor(2.1082), tensor(1.6827), tensor(1.9804), tensor(1.8133), tensor(1.8784), tensor(1.9243), tensor(1.8711), tensor(1.9311), tensor(1.9327), tensor(1.8430), tensor(1.9367), tensor(1.8520), tensor(2.0163), tensor(1.9580), tensor(1.9103), tensor(1.9198), tensor(1.7808), tensor(2.0757), tensor(1.9933), tensor(1.8498), tensor(1.8722), tensor(1.7309), tensor(1.6788), tensor(1.8531), tensor(1.7562), tensor(1.8733), tensor(1.9882), tensor(2.0404), tensor(1.8257), tensor(1.9703), tensor(1.8117), tensor(1.9316), tensor(1.9596), tensor(1.8660), tensor(1.8554), tensor(1.8918), tensor(1.8857), tensor(1.7315), tensor(1.9961), tensor(2.0891), tensor(1.9692), tensor(1.9327), tensor(1.9714), tensor(1.8739), tensor(1.8700), tensor(1.9008), tensor(2.1076), tensor(1.8935), tensor(2.0050), tensor(1.9182), tensor(1.9254), tensor(1.9070), tensor(1.8453), tensor(2.0123), tensor(1.8492), tensor(2.0247), tensor(1.8627), tensor(1.9983), tensor(1.8027), tensor(1.9193), tensor(1.8217), tensor(1.8621), tensor(1.9568), tensor(1.7141), tensor(1.9238), tensor(1.9198), tensor(1.8481), tensor(1.8178), tensor(1.8851), tensor(1.8016), tensor(2.0516), tensor(2.0107), tensor(2.0605), tensor(1.9591), tensor(1.9210), tensor(1.8217), tensor(1.9467), tensor(1.7808), tensor(1.8016), tensor(1.7012), tensor(1.8061), tensor(1.9339), tensor(2.1194), tensor(1.7999), tensor(1.9036), tensor(1.8632), tensor(1.9882), tensor(1.7909), tensor(2.0583), tensor(1.7663), tensor(1.8649), tensor(1.9815), tensor(1.7450), tensor(1.9877), tensor(1.7562), tensor(1.9367), tensor(1.8643), tensor(1.9636), tensor(2.0174), tensor(1.9484), tensor(1.7797), tensor(1.7763), tensor(1.8430), tensor(1.8189), tensor(2.0258), tensor(1.8436), tensor(1.9047), tensor(1.8559), tensor(1.8492), tensor(2.0140), tensor(2.0202), tensor(1.8896), tensor(1.8795), tensor(1.9075), tensor(1.9535), tensor(1.9759), tensor(1.8285), tensor(1.8397), tensor(1.9041), tensor(1.8436), tensor(2.0667), tensor(2.0303), tensor(1.9877), tensor(1.8862), tensor(2.0381), tensor(1.8800), tensor(1.9271), tensor(1.8515), tensor(1.8728), tensor(1.8285), tensor(1.7898), tensor(1.9826), tensor(2.0342), tensor(1.9030), tensor(1.9154), tensor(1.9529), tensor(2.0303), tensor(1.8470), tensor(1.9327), tensor(1.9193), ...
# {'mean_message_length': tensor(1.9082), 'mean_weighted_message_length': tensor(1.2337), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  101
# [tensor(1.8749), tensor(2.0072), tensor(1.8521), tensor(1.6948), tensor(1.8688), tensor(1.6759), tensor(1.8805), tensor(1.9238), tensor(1.9111), tensor(1.9344), tensor(1.9366), tensor(1.8077), tensor(1.7332), tensor(1.6820), tensor(1.9700), tensor(1.7871), tensor(1.9011), tensor(1.8727), tensor(1.8649), tensor(1.8933), tensor(1.7615), tensor(1.8316), tensor(1.9316), tensor(1.7938), tensor(1.7449), tensor(1.8088), tensor(1.9800), tensor(1.8521), tensor(1.8627), tensor(1.8516), tensor(1.7771), tensor(2.0617), tensor(1.8349), tensor(1.7571), tensor(1.8571), tensor(1.7693), tensor(1.8210), tensor(1.9111), tensor(1.9033), tensor(1.8471), tensor(1.8844), tensor(1.7349), tensor(1.8860), tensor(1.8110), tensor(1.9144), tensor(1.7865), tensor(1.8883), tensor(1.8877), tensor(1.6832), tensor(1.7799), tensor(1.7098), tensor(1.8216), tensor(1.7838), tensor(1.9644), tensor(1.8583), tensor(1.9594), tensor(1.7048), tensor(1.8132), tensor(2.0417), tensor(1.8933), tensor(2.0478), tensor(1.8644), tensor(1.7977), tensor(1.9450), tensor(1.9227), tensor(1.8822), tensor(1.9233), tensor(2.0712), tensor(1.9928), tensor(1.8722), tensor(1.8021), tensor(1.9650), tensor(1.9550), tensor(1.8388), tensor(1.9322), tensor(1.7982), tensor(1.7187), tensor(1.8093), tensor(1.8849), tensor(1.9233), tensor(1.5887), tensor(1.9283), tensor(1.8110), tensor(1.7665), tensor(1.7449), tensor(1.8822), tensor(1.9511), tensor(1.8405), tensor(1.8166), tensor(1.7977), tensor(1.9016), tensor(1.8872), tensor(1.7443), tensor(1.9722), tensor(1.8199), tensor(1.9055), tensor(1.7932), tensor(1.9327), tensor(1.8038), tensor(2.1078), tensor(1.8911), tensor(2.0767), tensor(2.0862), tensor(2.0428), tensor(1.9633), tensor(1.8066), tensor(1.9844), tensor(1.8082), tensor(1.8238), tensor(1.9439), tensor(1.6415), tensor(1.8855), tensor(2.0172), tensor(1.8794), tensor(1.9316), tensor(1.9250), tensor(1.9755), tensor(1.9805), tensor(1.8710), tensor(1.9939), tensor(1.9694), tensor(1.9811), tensor(1.9055), tensor(1.8744), tensor(1.8327), tensor(1.9555), tensor(1.8949), tensor(1.7571), tensor(1.7382), tensor(1.7827), tensor(1.7927), tensor(1.8549), tensor(1.9644), tensor(1.9200), tensor(1.8638), tensor(1.8166), tensor(1.7943), tensor(1.8860), tensor(1.9116), tensor(1.9322), tensor(1.8127), tensor(1.8610), tensor(1.9061), tensor(1.7265), tensor(1.7538), tensor(1.8927), tensor(1.8727), tensor(1.8444), tensor(2.0061), tensor(1.9377), tensor(1.8555), tensor(1.9477), tensor(1.9088), tensor(1.9616), tensor(1.8155), tensor(1.8449), tensor(1.8344), tensor(1.8749), tensor(1.7582), tensor(1.7810), tensor(1.9183), tensor(1.7960), tensor(1.9166), tensor(1.7977), tensor(1.7754), tensor(1.8066), tensor(1.8193), tensor(1.7493), tensor(1.7588), tensor(1.5664), tensor(1.8054), tensor(1.9305), tensor(1.9177), tensor(1.9233), tensor(1.8449), tensor(1.6287), tensor(1.9589), tensor(2.0139), tensor(1.7910), tensor(1.9327), tensor(1.8855), tensor(1.8455), tensor(1.7710), tensor(1.8983), tensor(1.9466), tensor(1.7343), tensor(1.8160), tensor(1.9100), tensor(1.9444), tensor(1.7204), tensor(1.8310), tensor(1.8872), tensor(1.7771), tensor(1.9022), tensor(1.8649), tensor(1.7515), tensor(1.8432), tensor(1.9211), tensor(1.6454), tensor(1.9405), tensor(1.7504), tensor(1.8777), tensor(1.9539), tensor(1.9244), tensor(1.9355), tensor(1.9700), tensor(1.8827), tensor(1.8171), tensor(1.8988), tensor(1.8983), tensor(1.8338), tensor(1.8738), tensor(1.8716), tensor(1.9767), tensor(1.9361), tensor(1.8955), tensor(1.6826), tensor(1.7482), tensor(1.8833), tensor(1.9505), tensor(1.7487), tensor(1.9644), tensor(1.8205), tensor(1.8599), tensor(1.8966), tensor(1.8866), tensor(1.9222), tensor(1.9372), tensor(1.9133), tensor(1.6876), tensor(1.9183), tensor(1.8560), tensor(1.8972), tensor(1.6365), tensor(1.8605), tensor(1.8193), tensor(1.7048), tensor(1.8844), tensor(1.9867), tensor(1.9122), tensor(1.7048), tensor(1.7432), tensor(1.8021), tensor(1.8905), tensor(1.7132), tensor(2.0072), tensor(1.7621), tensor(1.7354), tensor(1.8683), tensor(1.9055), ...
# {'mean_message_length': tensor(1.8614), 'mean_weighted_message_length': tensor(1.0817), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  93
# [tensor(1.6939), tensor(1.8756), tensor(1.5263), tensor(1.8509), tensor(1.8873), tensor(1.9327), tensor(1.8111), tensor(1.9243), tensor(1.9271), tensor(1.8806), tensor(1.8044), tensor(1.9165), tensor(1.8430), tensor(1.7831), tensor(1.9378), tensor(1.9064), tensor(1.8459), tensor(1.8386), tensor(1.7422), tensor(1.6878), tensor(1.7360), tensor(1.7870), tensor(1.6284), tensor(1.8167), tensor(1.7365), tensor(1.9114), tensor(1.7780), tensor(1.7046), tensor(1.9165), tensor(1.9608), tensor(1.8313), tensor(1.8251), tensor(1.9092), tensor(1.8189), tensor(1.7522), tensor(1.7904), tensor(1.7012), tensor(1.7270), tensor(1.7578), tensor(2.0107), tensor(1.8800), tensor(1.8767), tensor(1.7702), tensor(1.9182), tensor(1.9367), tensor(1.7696), tensor(1.9103), tensor(1.9540), tensor(1.8857), tensor(1.8868), tensor(1.9524), tensor(1.8851), tensor(1.7539), tensor(1.7601), tensor(1.8660), tensor(1.7562), tensor(1.8346), tensor(1.8795), tensor(1.8694), tensor(1.8122), tensor(1.7915), tensor(1.8094), tensor(1.7506), tensor(1.9198), tensor(1.8296), tensor(1.7377), tensor(1.9720), tensor(1.9064), tensor(1.8049), tensor(1.7119), tensor(1.8756), tensor(1.8531), tensor(1.8896), tensor(1.8744), tensor(1.8980), tensor(1.9518), tensor(1.7478), tensor(1.9608), tensor(1.8408), tensor(1.5874), tensor(1.9580), tensor(1.8817), tensor(1.8728), tensor(1.8683), tensor(1.8946), tensor(1.9058), tensor(1.6558), tensor(1.9888), tensor(1.9596), tensor(2.0202), tensor(1.9013), tensor(1.7562), tensor(1.8879), tensor(1.8632), tensor(1.7466), tensor(2.0432), tensor(1.9311), tensor(1.9221), tensor(1.7825), tensor(1.8868), tensor(1.9524), tensor(1.7601), tensor(1.9697), tensor(2.0622), tensor(1.8189), tensor(1.9367), tensor(1.6127), tensor(1.8812), tensor(1.9367), tensor(1.9389), tensor(1.8262), tensor(2.0465), tensor(1.8010), tensor(1.8268), tensor(1.8408), tensor(1.8711), tensor(1.8184), tensor(1.7393), tensor(1.7993), tensor(1.8761), tensor(1.7724), tensor(1.7702), tensor(1.6553), tensor(1.7735), tensor(1.8907), tensor(1.8655), tensor(1.9540), tensor(1.7808), tensor(1.7130), tensor(1.8812), tensor(1.5807), tensor(1.8341), tensor(2.0011), tensor(1.8879), tensor(1.8834), tensor(1.9737), tensor(1.7096), tensor(1.8105), tensor(1.8935), tensor(1.9053), tensor(1.5471), tensor(1.6519), tensor(2.0241), tensor(1.8072), tensor(1.9742), tensor(1.9496), tensor(1.9165), tensor(1.9467), tensor(1.8246), tensor(1.8935), tensor(1.7752), tensor(1.9490), tensor(1.8744), tensor(1.8571), tensor(1.8537), tensor(1.9714), tensor(1.8969), tensor(1.9910), tensor(1.7640), tensor(1.9596), tensor(1.8632), tensor(1.8672), tensor(2.0045), tensor(1.8985), tensor(1.8756), tensor(1.8845), tensor(1.9142), tensor(1.7068), tensor(1.8924), tensor(2.0151), tensor(1.7343), tensor(1.8520), tensor(1.9658), tensor(1.7595), tensor(2.1328), tensor(1.9776), tensor(1.8369), tensor(1.9086), tensor(1.9563), tensor(1.8862), tensor(1.7791), tensor(1.9748), tensor(1.6867), tensor(1.6362), tensor(1.8285), tensor(1.9288), tensor(1.9170), tensor(1.9697), tensor(1.9114), tensor(1.8862), tensor(2.0611), tensor(1.8302), tensor(1.9254), tensor(1.7186), tensor(1.8290), tensor(1.8128), tensor(1.7657), tensor(1.7848), tensor(1.7640), tensor(1.8004), tensor(1.9148), tensor(1.5953), tensor(1.9423), tensor(1.8498), tensor(1.9058), tensor(2.0123), tensor(2.0914), tensor(1.9417), tensor(1.8750), tensor(1.8531), tensor(1.8800), tensor(1.9535), tensor(1.9182), tensor(1.8957), tensor(1.7915), tensor(1.7141), tensor(1.8240), tensor(1.9299), tensor(1.9529), tensor(1.8173), tensor(1.8559), tensor(1.8918), tensor(1.9226), tensor(1.9210), tensor(1.7393), tensor(1.7556), tensor(1.9036), tensor(1.7287), tensor(1.9950), tensor(1.8217), tensor(1.8369), tensor(1.6328), tensor(1.9187), tensor(1.7494), tensor(1.7825), tensor(1.8425), tensor(1.7618), tensor(1.8156), tensor(1.8481), tensor(1.8845), tensor(1.8447), tensor(1.9260), tensor(1.8784), tensor(1.7791), tensor(1.7225), tensor(1.9652), tensor(1.7668), tensor(1.8907), tensor(1.8559), tensor(1.7932), ...
# {'mean_message_length': tensor(1.8495), 'mean_weighted_message_length': tensor(1.0448), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  101
# [tensor(1.9327), tensor(1.8236), tensor(1.9482), tensor(1.8247), tensor(2.0761), tensor(1.9074), tensor(1.9482), tensor(1.7993), tensor(1.8710), tensor(1.9421), tensor(1.8655), tensor(1.8501), tensor(1.8434), tensor(1.8490), tensor(1.9449), tensor(1.7762), tensor(1.7977), tensor(1.7856), tensor(1.9531), tensor(1.7519), tensor(2.0424), tensor(1.9598), tensor(1.8197), tensor(1.9195), tensor(1.9256), tensor(2.0116), tensor(1.8153), tensor(1.8848), tensor(1.9476), tensor(1.9449), tensor(1.8666), tensor(1.8219), tensor(1.9686), tensor(1.9316), tensor(1.8225), tensor(1.9322), tensor(1.7971), tensor(1.9256), tensor(1.9030), tensor(1.7977), tensor(1.8324), tensor(1.9559), tensor(1.8710), tensor(2.0028), tensor(1.9405), tensor(1.7977), tensor(1.9504), tensor(2.0309), tensor(1.7448), tensor(1.9173), tensor(1.6406), tensor(1.8942), tensor(1.7839), tensor(1.8875), tensor(1.9278), tensor(1.8060), tensor(1.8258), tensor(1.9372), tensor(1.9746), tensor(1.8357), tensor(1.8820), tensor(1.9851), tensor(1.8655), tensor(1.8644), tensor(1.9465), tensor(1.9669), tensor(1.8831), tensor(1.7437), tensor(1.9112), tensor(1.9564), tensor(1.8572), tensor(1.9487), tensor(1.9256), tensor(1.9642), tensor(1.9283), tensor(1.9035), tensor(1.6516), tensor(1.9129), tensor(1.9090), tensor(1.9520), tensor(1.9085), tensor(1.9493), tensor(1.9344), tensor(1.8308), tensor(1.8087), tensor(1.9537), tensor(1.8054), tensor(1.9201), tensor(1.9151), tensor(1.8920), tensor(1.7696), tensor(1.9868), tensor(1.9857), tensor(1.7707), tensor(1.8192), tensor(1.9046), tensor(1.8517), tensor(1.9906), tensor(1.9140), tensor(1.8396), tensor(1.9372), tensor(1.9305), tensor(1.9046), tensor(1.8280), tensor(1.9146), tensor(1.8649), tensor(1.8512), tensor(1.8341), tensor(1.8699), tensor(2.0127), tensor(1.9008), tensor(1.9267), tensor(1.9647), tensor(1.8026), tensor(1.9052), tensor(1.8942), tensor(1.9664), tensor(1.8434), tensor(1.9008), tensor(1.8186), tensor(1.8517), tensor(2.0039), tensor(1.9421), tensor(1.7960), tensor(1.6180), tensor(1.8782), tensor(1.7839), tensor(1.9041), tensor(1.9416), tensor(1.8815), tensor(1.9316), tensor(1.8931), tensor(1.9272), tensor(1.9520), tensor(1.8870), tensor(1.7751), tensor(1.9366), tensor(1.9079), tensor(1.9972), tensor(1.8352), tensor(1.9383), tensor(1.8275), tensor(1.8942), tensor(1.8313), tensor(1.7514), tensor(1.8181), tensor(1.8026), tensor(1.8710), tensor(1.9504), tensor(1.7707), tensor(1.9768), tensor(1.8622), tensor(1.7778), tensor(1.9614), tensor(1.9636), tensor(1.8423), tensor(1.9068), tensor(1.6951), tensor(1.8153), tensor(1.9449), tensor(1.7211), tensor(1.8931), tensor(1.8727), tensor(1.8848), tensor(1.9157), tensor(1.8837), tensor(1.9046), tensor(1.9289), tensor(1.9046), tensor(1.8677), tensor(1.8611), tensor(2.0524), tensor(2.0237), tensor(1.9300), tensor(1.9223), tensor(1.8153), tensor(1.9068), tensor(1.8396), tensor(1.9261), tensor(1.7602), tensor(1.8820), tensor(1.7635), tensor(1.9735), tensor(1.9256), tensor(2.0154), tensor(1.9129), tensor(1.9785), tensor(1.9030), tensor(1.9201), tensor(1.8341), tensor(1.9311), tensor(1.8914), tensor(1.9796), tensor(1.8313), tensor(2.0474), tensor(1.9377), tensor(1.8991), tensor(2.0072), tensor(2.0259), tensor(1.8219), tensor(1.7326), tensor(1.9526), tensor(1.8467), tensor(1.9289), tensor(1.7062), tensor(1.9498), tensor(1.8583), tensor(1.7652), tensor(1.8203), tensor(1.9796), tensor(1.7817), tensor(1.9206), tensor(2.0584), tensor(1.9598), tensor(1.8567), tensor(1.7701), tensor(1.8269), tensor(1.8010), tensor(1.8550), tensor(1.5843), tensor(1.9019), tensor(1.8313), tensor(1.9245), tensor(1.8903), tensor(1.9824), tensor(1.8346), tensor(1.8892), tensor(1.9553), tensor(2.0347), tensor(1.8837), tensor(1.9123), tensor(1.7233), tensor(1.8771), tensor(1.8561), tensor(1.7486), tensor(1.8142), tensor(1.9421), tensor(1.8269), tensor(1.9190), tensor(1.8931), tensor(1.8142), tensor(1.9416), tensor(1.8440), tensor(1.9030), tensor(1.8539), tensor(1.7900), tensor(1.9405), tensor(1.6880), tensor(1.9471), tensor(1.9372), ...
# {'mean_message_length': tensor(1.8812), 'mean_weighted_message_length': tensor(1.2084), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  380
# [tensor(2.0395), tensor(1.9505), tensor(2.0516), tensor(2.0650), tensor(2.0451), tensor(1.9476), tensor(1.9626), tensor(1.9965), tensor(1.9774), tensor(2.0069), tensor(2.0215), tensor(1.9782), tensor(1.9853), tensor(1.9681), tensor(2.0319), tensor(2.0848), tensor(1.9704), tensor(1.9710), tensor(2.0273), tensor(2.0265), tensor(1.9658), tensor(2.1299), tensor(2.0024), tensor(1.9395), tensor(2.0416), tensor(1.9961), tensor(1.9673), tensor(2.0099), tensor(1.9737), tensor(2.0348), tensor(2.0147), tensor(2.0393), tensor(1.9692), tensor(2.0666), tensor(2.0482), tensor(2.0539), tensor(2.0241), tensor(2.0082), tensor(2.0225), tensor(1.9917), tensor(2.0069), tensor(2.1322), tensor(2.1016), tensor(2.0680), tensor(1.9753), tensor(2.0351), tensor(2.0282), tensor(2.0067), tensor(2.0159), tensor(2.0716), tensor(1.9790), tensor(2.0454), tensor(2.0303), tensor(2.0003), tensor(2.0092), tensor(2.0327), tensor(2.0080), tensor(2.0516), tensor(2.0350), tensor(2.0496), tensor(1.9980), tensor(1.9929), tensor(2.0020), tensor(2.0155), tensor(1.8795), tensor(2.0215), tensor(2.0102), tensor(2.0274), tensor(2.0508), tensor(2.0852), tensor(2.0035), tensor(2.0191), tensor(1.9602), tensor(2.0565), tensor(1.9391), tensor(1.9918), tensor(1.9793), tensor(2.0406), tensor(1.9356), tensor(2.0210), tensor(2.0228), tensor(1.9827), tensor(2.0071), tensor(2.0266), tensor(1.9938), tensor(2.0561), tensor(2.0011), tensor(2.0095), tensor(2.0139), tensor(2.0600), tensor(1.9793), tensor(1.9747), tensor(2.0501), tensor(2.0389), tensor(1.9557), tensor(1.9976), tensor(2.0646), tensor(2.0684), tensor(1.9391), tensor(1.9374), tensor(1.9921), tensor(1.9417), tensor(2.0410), tensor(2.0828), tensor(2.0471), tensor(1.9167), tensor(2.0169), tensor(2.0417), tensor(2.0041), tensor(1.9770), tensor(1.9945), tensor(2.0000), tensor(1.9823), tensor(2.0095), tensor(1.9874), tensor(1.9589), tensor(2.0156), tensor(2.0361), tensor(1.8772), tensor(1.9956), tensor(2.0029), tensor(1.9679), tensor(1.9935), tensor(1.9808), tensor(2.0116), tensor(2.0549), tensor(1.9651), tensor(2.0919), tensor(2.0113), tensor(1.9837), tensor(2.0538), tensor(1.9746), tensor(1.9650), tensor(1.9966), tensor(1.9722), tensor(1.9951), tensor(2.0196), tensor(2.0011), tensor(2.0128), tensor(2.0262), tensor(2.0647), tensor(1.9841), tensor(2.0551), tensor(2.0361), tensor(1.9277), tensor(2.0338), tensor(2.0435), tensor(1.9707), tensor(2.0168), tensor(1.9912), tensor(2.0220), tensor(1.9821), tensor(2.0636), tensor(1.9855), tensor(2.0183), tensor(2.0190), tensor(2.0188), tensor(2.0223), tensor(1.9937), tensor(2.0031), tensor(2.0380), tensor(2.0190), tensor(2.0389), tensor(2.0400), tensor(1.9942), tensor(2.0634), tensor(2.0435), tensor(1.9825), tensor(1.9733), tensor(2.0173), tensor(1.9553), tensor(2.0467), tensor(2.0185), tensor(2.0030), tensor(2.0660), tensor(2.0312), tensor(1.9839), tensor(1.9649), tensor(2.0014), tensor(2.0146), tensor(2.0256), tensor(2.0755), tensor(2.0350), tensor(2.0274), tensor(2.0363), tensor(2.0579), tensor(2.0244), tensor(2.0446), tensor(1.9792), tensor(2.0408), tensor(1.9736), tensor(2.0771), tensor(2.0389), tensor(2.0290), tensor(1.9735), tensor(2.0338), tensor(2.0310), tensor(1.9910), tensor(1.9838), tensor(2.0497), tensor(1.9641), tensor(2.0585), tensor(2.0427), tensor(2.0492), tensor(2.0370), tensor(2.0502), tensor(2.0410), tensor(2.0628), tensor(1.9665), tensor(2.0421), tensor(1.9784), tensor(1.9596), tensor(2.0187), tensor(2.0173), tensor(2.0156), tensor(2.0629), tensor(1.9815), tensor(2.0128), tensor(2.0667), tensor(1.9727), tensor(2.0612), tensor(1.9746), tensor(1.9896), tensor(2.0540), tensor(1.9969), tensor(2.0235), tensor(1.9475), tensor(1.9453), tensor(1.9859), tensor(1.9684), tensor(1.9360), tensor(1.9299), tensor(2.0696), tensor(2.0236), tensor(1.9973), tensor(2.0161), tensor(1.9994), tensor(2.0011), tensor(1.9521), tensor(1.9997), tensor(2.0912), tensor(1.9952), tensor(2.0403), tensor(2.0247), tensor(2.0462), tensor(2.0438), tensor(2.0163), tensor(1.9231), tensor(2.0156), tensor(2.1595), ...
# {'mean_message_length': tensor(2.0132), 'mean_weighted_message_length': tensor(1.4848), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  400
# [tensor(2.1358), tensor(2.0251), tensor(2.1853), tensor(2.1234), tensor(2.1355), tensor(2.1716), tensor(2.0645), tensor(2.1660), tensor(2.1540), tensor(2.1048), tensor(2.1353), tensor(2.1808), tensor(2.0355), tensor(2.1407), tensor(2.1449), tensor(2.1170), tensor(2.0653), tensor(2.0480), tensor(2.1398), tensor(2.1778), tensor(2.0909), tensor(2.2229), tensor(2.1794), tensor(2.2174), tensor(2.2238), tensor(2.1524), tensor(2.1672), tensor(2.2187), tensor(2.1522), tensor(2.1174), tensor(2.1392), tensor(2.0438), tensor(2.2695), tensor(2.2070), tensor(2.1493), tensor(2.0952), tensor(2.1345), tensor(2.1342), tensor(2.1452), tensor(2.0395), tensor(2.1809), tensor(2.2179), tensor(2.1026), tensor(2.1163), tensor(2.0467), tensor(2.1545), tensor(2.0709), tensor(2.2185), tensor(2.2199), tensor(2.1478), tensor(2.1095), tensor(2.1059), tensor(2.1785), tensor(2.0621), tensor(2.1219), tensor(2.1789), tensor(2.0939), tensor(2.1714), tensor(2.0970), tensor(2.2323), tensor(2.1634), tensor(2.2301), tensor(2.1705), tensor(2.1421), tensor(2.0889), tensor(2.1630), tensor(2.1774), tensor(2.3416), tensor(2.1657), tensor(2.1986), tensor(2.0828), tensor(2.1695), tensor(2.1303), tensor(2.1979), tensor(2.1111), tensor(2.1289), tensor(2.1921), tensor(2.2584), tensor(2.1005), tensor(2.2075), tensor(2.0779), tensor(2.1184), tensor(2.1220), tensor(2.1325), tensor(2.1773), tensor(2.0831), tensor(2.1634), tensor(2.1541), tensor(2.1239), tensor(2.1953), tensor(2.2152), tensor(2.1152), tensor(2.1384), tensor(2.0779), tensor(2.1356), tensor(2.1461), tensor(2.1693), tensor(2.0728), tensor(2.1506), tensor(2.1727), tensor(2.1277), tensor(2.0824), tensor(2.2115), tensor(2.1321), tensor(2.1599), tensor(2.1786), tensor(2.0940), tensor(2.2194), tensor(2.0701), tensor(2.1469), tensor(2.2234), tensor(2.1794), tensor(2.1085), tensor(2.1232), tensor(2.1313), tensor(2.2739), tensor(2.1951), tensor(2.2178), tensor(2.1136), tensor(2.0686), tensor(2.1796), tensor(2.1824), tensor(2.1297), tensor(2.1540), tensor(2.1011), tensor(2.0759), tensor(2.1428), tensor(2.1149), tensor(2.1043), tensor(2.2205), tensor(2.1255), tensor(2.0768), tensor(2.1357), tensor(2.1816), tensor(2.2261), tensor(2.0583), tensor(2.2598), tensor(2.0965), tensor(2.1698), tensor(2.1090), tensor(2.1773), tensor(2.1084), tensor(2.0439), tensor(2.1645), tensor(2.1021), tensor(2.1057), tensor(2.1631), tensor(2.1764), tensor(2.1014), tensor(2.1055), tensor(2.1238), tensor(2.2022), tensor(2.2188), tensor(2.1832), tensor(2.1683), tensor(2.1502), tensor(2.2086), tensor(2.1374), tensor(2.0910), tensor(2.1920), tensor(2.2098), tensor(2.0461), tensor(2.1130), tensor(2.2101), tensor(2.1349), tensor(2.0789), tensor(2.1773), tensor(2.1370), tensor(2.1887), tensor(2.1573), tensor(2.0887), tensor(2.2130), tensor(2.0665), tensor(2.1166), tensor(2.1366), tensor(2.0656), tensor(2.2155), tensor(2.1607), tensor(2.1079), tensor(2.0877), tensor(2.2138), tensor(2.2142), tensor(2.1107), tensor(2.1753), tensor(2.1958), tensor(2.1439), tensor(2.0878), tensor(2.0133), tensor(2.0728), tensor(2.0943), tensor(2.1996), tensor(2.1332), tensor(2.1533), tensor(2.0956), tensor(2.1328), tensor(2.2029), tensor(2.1077), tensor(2.1244), tensor(2.1869), tensor(2.1614), tensor(2.1037), tensor(2.0209), tensor(2.2112), tensor(2.0858), tensor(2.1576), tensor(2.1589), tensor(2.1935), tensor(2.2480), tensor(2.1540), tensor(2.0255), tensor(2.1775), tensor(2.1111), tensor(2.1028), tensor(2.1677), tensor(2.1376), tensor(2.1628), tensor(2.1706), tensor(2.2431), tensor(2.1704), tensor(2.0794), tensor(2.2509), tensor(2.1468), tensor(2.0988), tensor(2.1498), tensor(2.1083), tensor(2.1604), tensor(2.1026), tensor(2.1709), tensor(2.2290), tensor(2.0198), tensor(2.1018), tensor(2.1122), tensor(2.1533), tensor(2.0862), tensor(2.1462), tensor(2.1190), tensor(2.0948), tensor(2.2700), tensor(2.2049), tensor(2.1643), tensor(2.1345), tensor(2.1505), tensor(2.1063), tensor(2.1775), tensor(2.2019), tensor(2.1146), tensor(2.1575), tensor(2.1655), tensor(2.1977), tensor(2.1359), ...
# {'mean_message_length': tensor(2.1450), 'mean_weighted_message_length': tensor(1.3626), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  369
# [tensor(1.9857), tensor(2.0170), tensor(1.9760), tensor(2.0491), tensor(1.9829), tensor(2.0021), tensor(1.9692), tensor(1.9953), tensor(1.9647), tensor(1.9833), tensor(1.9622), tensor(1.9697), tensor(1.9977), tensor(1.9807), tensor(2.0141), tensor(1.9784), tensor(1.9970), tensor(1.9957), tensor(1.9848), tensor(1.9876), tensor(1.9903), tensor(1.9894), tensor(1.9857), tensor(1.9918), tensor(2.0094), tensor(1.9696), tensor(1.9687), tensor(1.9907), tensor(1.9888), tensor(1.9888), tensor(2.0291), tensor(2.0020), tensor(1.9745), tensor(2.0069), tensor(2.0231), tensor(1.9999), tensor(2.0112), tensor(2.0058), tensor(1.9987), tensor(2.0121), tensor(1.9938), tensor(2.0002), tensor(2.0144), tensor(1.9347), tensor(2.0171), tensor(1.9980), tensor(1.9704), tensor(1.9962), tensor(2.0250), tensor(2.0028), tensor(1.9724), tensor(2.0086), tensor(1.9750), tensor(2.0144), tensor(1.9359), tensor(2.0184), tensor(1.9669), tensor(1.9791), tensor(2.0208), tensor(2.0339), tensor(1.9733), tensor(1.9894), tensor(2.0045), tensor(1.9779), tensor(1.9849), tensor(2.0109), tensor(1.9964), tensor(1.9898), tensor(1.9674), tensor(1.9888), tensor(1.9889), tensor(1.9744), tensor(2.0005), tensor(2.0356), tensor(1.9802), tensor(1.9773), tensor(1.9681), tensor(2.0021), tensor(2.0222), tensor(2.0006), tensor(1.9753), tensor(2.0711), tensor(1.9900), tensor(1.9696), tensor(1.9882), tensor(1.9886), tensor(1.9980), tensor(1.9590), tensor(2.0267), tensor(1.9860), tensor(1.9306), tensor(2.0007), tensor(1.9515), tensor(1.9873), tensor(2.0027), tensor(1.9503), tensor(2.0300), tensor(1.9876), tensor(2.0194), tensor(2.0298), tensor(2.0026), tensor(2.0188), tensor(1.9765), tensor(1.9784), tensor(1.9754), tensor(1.9854), tensor(1.9804), tensor(2.0162), tensor(2.0288), tensor(2.0181), tensor(1.9863), tensor(1.9759), tensor(1.9871), tensor(1.9867), tensor(1.9870), tensor(2.0002), tensor(2.0282), tensor(1.9954), tensor(1.9911), tensor(2.0142), tensor(1.9815), tensor(1.9509), tensor(2.0288), tensor(2.0138), tensor(1.9880), tensor(2.0019), tensor(2.0413), tensor(1.9335), tensor(1.9907), tensor(2.0080), tensor(2.0203), tensor(2.0086), tensor(2.0134), tensor(2.0137), tensor(1.9714), tensor(1.9678), tensor(1.9948), tensor(1.9774), tensor(2.0211), tensor(2.0033), tensor(2.0134), tensor(1.9958), tensor(1.9857), tensor(2.0016), tensor(1.9632), tensor(1.9743), tensor(1.9546), tensor(2.0052), tensor(2.0004), tensor(1.9958), tensor(2.0173), tensor(1.9693), tensor(1.9823), tensor(2.0092), tensor(1.9597), tensor(1.9809), tensor(2.0184), tensor(1.9783), tensor(1.9739), tensor(2.0079), tensor(2.0088), tensor(1.9827), tensor(2.0044), tensor(2.0032), tensor(2.0128), tensor(1.9764), tensor(2.0133), tensor(1.9526), tensor(1.9438), tensor(2.0076), tensor(1.9826), tensor(2.0003), tensor(2.0182), tensor(2.0465), tensor(1.9937), tensor(1.9780), tensor(2.0298), tensor(1.9767), tensor(1.9384), tensor(1.9885), tensor(2.0092), tensor(2.0258), tensor(1.9796), tensor(2.0133), tensor(2.0003), tensor(1.9705), tensor(2.0165), tensor(2.0115), tensor(1.9796), tensor(2.0046), tensor(1.9843), tensor(1.9833), tensor(2.0009), tensor(2.0184), tensor(2.0167), tensor(1.9994), tensor(1.9601), tensor(2.0029), tensor(2.0012), tensor(2.0036), tensor(1.9739), tensor(1.9969), tensor(1.9693), tensor(1.9938), tensor(2.0023), tensor(1.9820), tensor(2.0010), tensor(2.0237), tensor(2.0240), tensor(1.9866), tensor(1.9591), tensor(2.0246), tensor(2.0156), tensor(1.9453), tensor(1.9562), tensor(2.0282), tensor(2.0128), tensor(1.9758), tensor(1.9885), tensor(1.9751), tensor(2.0089), tensor(1.9741), tensor(1.9904), tensor(1.9720), tensor(2.0064), tensor(1.9941), tensor(1.9661), tensor(2.0167), tensor(1.9874), tensor(1.9749), tensor(2.0269), tensor(1.9900), tensor(1.9797), tensor(2.0150), tensor(2.0031), tensor(1.9810), tensor(2.0006), tensor(2.0409), tensor(1.9565), tensor(1.9943), tensor(1.9782), tensor(1.9765), tensor(1.9534), tensor(1.9810), tensor(1.9716), tensor(1.9907), tensor(2.0040), tensor(2.0153), tensor(1.9954), tensor(2.0143), ...
# {'mean_message_length': tensor(1.9946), 'mean_weighted_message_length': tensor(1.6888), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  340
# [tensor(2.2574), tensor(2.2640), tensor(2.2708), tensor(2.1272), tensor(2.1903), tensor(2.2217), tensor(2.2296), tensor(2.1370), tensor(2.2443), tensor(2.1099), tensor(2.1803), tensor(2.0970), tensor(2.1631), tensor(2.1571), tensor(2.2488), tensor(2.1661), tensor(2.1912), tensor(2.2525), tensor(2.1975), tensor(2.1363), tensor(2.2815), tensor(2.1994), tensor(2.2293), tensor(2.2080), tensor(2.1756), tensor(2.1379), tensor(2.0751), tensor(2.2376), tensor(2.1616), tensor(2.2743), tensor(2.0980), tensor(2.1545), tensor(2.1838), tensor(2.2835), tensor(2.2005), tensor(2.1893), tensor(2.1798), tensor(1.9815), tensor(2.1963), tensor(2.1746), tensor(2.1227), tensor(2.1490), tensor(2.1879), tensor(2.2531), tensor(2.1208), tensor(2.3712), tensor(2.1002), tensor(2.2258), tensor(2.1207), tensor(2.1460), tensor(2.2074), tensor(2.1725), tensor(2.1643), tensor(2.2213), tensor(2.2587), tensor(2.1588), tensor(2.2692), tensor(2.1814), tensor(2.2970), tensor(2.1849), tensor(2.2567), tensor(2.2392), tensor(2.1484), tensor(2.2005), tensor(2.1685), tensor(2.1918), tensor(2.1314), tensor(2.2689), tensor(2.1768), tensor(2.1828), tensor(2.2888), tensor(2.2228), tensor(2.2617), tensor(2.1439), tensor(2.1926), tensor(2.2665), tensor(2.1934), tensor(2.0961), tensor(2.1533), tensor(2.1740), tensor(2.2977), tensor(2.1613), tensor(2.2107), tensor(2.1471), tensor(2.1456), tensor(2.2016), tensor(2.2455), tensor(2.2871), tensor(2.2100), tensor(2.1650), tensor(2.2114), tensor(2.2543), tensor(2.2067), tensor(2.2039), tensor(2.2174), tensor(2.1015), tensor(2.1589), tensor(2.2782), tensor(2.1674), tensor(2.1952), tensor(2.2067), tensor(2.1688), tensor(2.3071), tensor(2.1019), tensor(2.2333), tensor(2.2448), tensor(2.3384), tensor(2.3353), tensor(2.2030), tensor(2.0707), tensor(2.2743), tensor(2.1490), tensor(2.2450), tensor(2.2977), tensor(2.2009), tensor(2.3032), tensor(2.1485), tensor(2.1843), tensor(2.2039), tensor(2.1077), tensor(2.1495), tensor(2.1411), tensor(2.2573), tensor(2.2561), tensor(2.1563), tensor(2.1926), tensor(2.1583), tensor(2.1393), tensor(2.2961), tensor(2.2409), tensor(2.2578), tensor(2.2649), tensor(2.1645), tensor(2.2388), tensor(2.0365), tensor(2.2429), tensor(2.2026), tensor(2.2189), tensor(2.3020), tensor(2.1551), tensor(2.1646), tensor(2.2970), tensor(2.1303), tensor(2.3277), tensor(2.1907), tensor(2.1411), tensor(2.1439), tensor(2.2461), tensor(2.2244), tensor(2.0736), tensor(2.2206), tensor(2.0921), tensor(2.1828), tensor(2.1764), tensor(2.1883), tensor(2.2088), tensor(2.2074), tensor(2.2094), tensor(2.2662), tensor(2.1317), tensor(2.2513), tensor(2.0781), tensor(2.1788), tensor(2.2456), tensor(2.1493), tensor(2.1576), tensor(2.1508), tensor(2.1858), tensor(2.1410), tensor(2.2262), tensor(2.3177), tensor(2.1988), tensor(2.2055), tensor(2.1378), tensor(2.2170), tensor(2.1391), tensor(1.9915), tensor(2.2076), tensor(2.1793), tensor(2.1547), tensor(2.1176), tensor(2.2209), tensor(2.1733), tensor(2.1745), tensor(2.2868), tensor(2.1977), tensor(2.2076), tensor(2.1599), tensor(2.2196), tensor(2.0927), tensor(2.2471), tensor(2.1195), tensor(2.1807), tensor(2.2858), tensor(2.1825), tensor(2.2143), tensor(2.1190), tensor(2.2153), tensor(2.3183), tensor(2.2020), tensor(2.2858), tensor(2.1528), tensor(2.1461), tensor(2.2093), tensor(2.1501), tensor(2.2249), tensor(2.1854), tensor(2.2401), tensor(2.2067), tensor(2.2325), tensor(2.1279), tensor(2.1500), tensor(2.1089), tensor(2.1891), tensor(2.1782), tensor(2.2358), tensor(2.1382), tensor(2.1521), tensor(2.1118), tensor(2.2275), tensor(2.1948), tensor(2.2137), tensor(2.2361), tensor(2.1057), tensor(2.2476), tensor(2.1130), tensor(2.1950), tensor(2.1604), tensor(2.1482), tensor(2.1047), tensor(2.0665), tensor(2.1477), tensor(2.2993), tensor(2.2590), tensor(2.2293), tensor(2.3408), tensor(2.2090), tensor(2.2989), tensor(2.1713), tensor(2.2651), tensor(2.2696), tensor(2.2671), tensor(2.1305), tensor(2.1655), tensor(2.1780), tensor(2.1713), tensor(2.2767), tensor(2.1019), tensor(2.0839), tensor(2.1670), ...
# {'mean_message_length': tensor(2.1882), 'mean_weighted_message_length': tensor(1.4850), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  358
# [tensor(2.1140), tensor(2.0157), tensor(2.0310), tensor(2.0437), tensor(1.9996), tensor(1.9919), tensor(1.9853), tensor(2.0800), tensor(1.9978), tensor(2.0273), tensor(1.9418), tensor(1.9146), tensor(2.0789), tensor(1.9856), tensor(2.0658), tensor(2.0361), tensor(2.0719), tensor(1.9043), tensor(1.9471), tensor(1.9578), tensor(2.1048), tensor(2.0530), tensor(1.9592), tensor(2.0083), tensor(1.9697), tensor(2.0392), tensor(2.0425), tensor(2.0773), tensor(2.0978), tensor(2.0072), tensor(2.0293), tensor(2.0633), tensor(2.0885), tensor(2.0718), tensor(2.0443), tensor(1.9832), tensor(2.0003), tensor(2.0844), tensor(2.0116), tensor(2.0179), tensor(1.9884), tensor(2.0369), tensor(2.0827), tensor(2.0832), tensor(1.9554), tensor(2.2062), tensor(2.0186), tensor(1.9968), tensor(2.1701), tensor(1.9524), tensor(2.0388), tensor(2.0385), tensor(2.0445), tensor(1.9603), tensor(1.9958), tensor(2.0640), tensor(2.0490), tensor(2.1827), tensor(2.0971), tensor(1.9191), tensor(2.0907), tensor(1.9045), tensor(2.1479), tensor(2.1028), tensor(2.0005), tensor(1.9334), tensor(1.9886), tensor(1.9997), tensor(2.0025), tensor(1.9329), tensor(2.0376), tensor(2.1412), tensor(2.0141), tensor(2.0509), tensor(2.0442), tensor(2.0982), tensor(1.9926), tensor(2.0495), tensor(2.1147), tensor(2.0888), tensor(1.9560), tensor(2.0148), tensor(2.0340), tensor(2.0343), tensor(2.0037), tensor(2.0176), tensor(1.9539), tensor(2.0198), tensor(2.0499), tensor(1.9246), tensor(2.0665), tensor(2.0848), tensor(2.0021), tensor(2.0239), tensor(2.0450), tensor(2.0171), tensor(1.9889), tensor(1.9799), tensor(1.9710), tensor(2.0293), tensor(2.1382), tensor(2.1109), tensor(2.0502), tensor(2.0836), tensor(2.1527), tensor(1.9589), tensor(1.9998), tensor(1.9773), tensor(2.0301), tensor(1.9506), tensor(2.0544), tensor(2.0280), tensor(1.9566), tensor(1.9950), tensor(2.0720), tensor(2.0470), tensor(1.9165), tensor(2.0131), tensor(2.0213), tensor(2.0319), tensor(2.0678), tensor(2.0752), tensor(2.1177), tensor(2.0341), tensor(1.8785), tensor(1.8890), tensor(1.9698), tensor(2.1382), tensor(2.0798), tensor(2.1921), tensor(2.1308), tensor(2.0177), tensor(2.0072), tensor(2.0009), tensor(2.0414), tensor(1.9871), tensor(2.0367), tensor(2.0287), tensor(2.1067), tensor(2.0612), tensor(2.0352), tensor(2.1560), tensor(2.0291), tensor(2.0228), tensor(2.0229), tensor(2.0032), tensor(2.0239), tensor(2.0353), tensor(2.0618), tensor(1.9878), tensor(2.1008), tensor(2.0283), tensor(2.0204), tensor(1.9407), tensor(2.1552), tensor(2.0072), tensor(1.9826), tensor(2.0855), tensor(1.9965), tensor(2.0595), tensor(2.0848), tensor(2.0400), tensor(2.0264), tensor(2.0593), tensor(2.0983), tensor(2.0285), tensor(2.0133), tensor(2.0218), tensor(2.0138), tensor(2.1304), tensor(1.8937), tensor(2.1053), tensor(1.9322), tensor(2.0010), tensor(2.1064), tensor(2.0043), tensor(2.0411), tensor(2.0243), tensor(2.0251), tensor(2.0159), tensor(2.0316), tensor(2.0257), tensor(2.0789), tensor(1.8602), tensor(1.9174), tensor(1.9586), tensor(1.9877), tensor(2.0970), tensor(2.0284), tensor(2.0772), tensor(2.1164), tensor(2.0770), tensor(2.0547), tensor(2.0372), tensor(2.0486), tensor(2.0630), tensor(1.9876), tensor(2.0171), tensor(1.9694), tensor(2.0421), tensor(2.0053), tensor(2.0691), tensor(2.1112), tensor(2.0958), tensor(2.1374), tensor(2.0426), tensor(1.9347), tensor(1.9764), tensor(2.0465), tensor(2.0736), tensor(1.9360), tensor(2.0687), tensor(2.0093), tensor(2.0554), tensor(1.9500), tensor(2.0199), tensor(2.0366), tensor(1.9962), tensor(2.0307), tensor(1.9684), tensor(2.0319), tensor(2.0328), tensor(1.9246), tensor(2.0152), tensor(2.0213), tensor(1.9211), tensor(2.0188), tensor(1.9968), tensor(2.0488), tensor(2.0512), tensor(1.9883), tensor(2.1294), tensor(1.9258), tensor(2.0033), tensor(1.8992), tensor(2.0688), tensor(2.0617), tensor(2.0152), tensor(2.0938), tensor(1.8754), tensor(2.0237), tensor(1.9696), tensor(2.0048), tensor(1.9429), tensor(1.9170), tensor(2.2176), tensor(1.9932), tensor(2.0238), tensor(2.0140), tensor(2.0560), ...
# {'mean_message_length': tensor(2.0335), 'mean_weighted_message_length': tensor(1.3419), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  202
# [tensor(2.0213), tensor(1.9846), tensor(2.0384), tensor(1.9026), tensor(2.0802), tensor(2.0018), tensor(1.9252), tensor(2.0749), tensor(1.9635), tensor(2.0332), tensor(2.1386), tensor(1.9428), tensor(1.9928), tensor(2.0647), tensor(1.9629), tensor(2.0984), tensor(2.0484), tensor(1.9111), tensor(1.9160), tensor(1.9827), tensor(1.9319), tensor(2.0985), tensor(1.8613), tensor(1.8860), tensor(1.9504), tensor(2.0075), tensor(1.9882), tensor(2.0953), tensor(2.0863), tensor(2.0343), tensor(1.9157), tensor(2.0571), tensor(1.9977), tensor(1.9452), tensor(2.2485), tensor(1.9492), tensor(1.9930), tensor(1.8188), tensor(1.9648), tensor(1.8047), tensor(1.9941), tensor(1.8449), tensor(1.9819), tensor(2.0655), tensor(2.0602), tensor(1.9479), tensor(2.3288), tensor(2.2028), tensor(2.0816), tensor(2.1292), tensor(2.0015), tensor(2.0498), tensor(2.1721), tensor(1.9621), tensor(2.3095), tensor(1.9552), tensor(2.0735), tensor(1.9017), tensor(2.1139), tensor(2.0593), tensor(2.0167), tensor(1.9368), tensor(2.1502), tensor(2.0145), tensor(2.0134), tensor(2.0388), tensor(1.8280), tensor(1.9539), tensor(2.0256), tensor(2.0305), tensor(2.2145), tensor(2.1212), tensor(2.0843), tensor(1.9034), tensor(2.1516), tensor(1.9249), tensor(2.2124), tensor(1.9106), tensor(1.8641), tensor(2.0539), tensor(2.0496), tensor(1.9389), tensor(1.9670), tensor(1.8546), tensor(1.8096), tensor(2.0147), tensor(2.0187), tensor(2.0459), tensor(2.0430), tensor(1.9014), tensor(1.9026), tensor(1.9590), tensor(1.9065), tensor(1.9534), tensor(1.9868), tensor(2.0033), tensor(2.0673), tensor(1.9430), tensor(2.0017), tensor(2.0278), tensor(2.1126), tensor(2.1941), tensor(1.9332), tensor(2.0560), tensor(2.0518), tensor(2.0080), tensor(2.0028), tensor(1.9020), tensor(1.9037), tensor(2.0391), tensor(1.9554), tensor(2.0475), tensor(1.9104), tensor(2.0207), tensor(2.0175), tensor(2.0017), tensor(2.1728), tensor(1.9437), tensor(2.1315), tensor(2.0031), tensor(1.9444), tensor(2.1595), tensor(1.9790), tensor(1.9898), tensor(2.0806), tensor(2.2048), tensor(1.9974), tensor(2.2276), tensor(2.0664), tensor(2.1965), tensor(1.8609), tensor(2.1039), tensor(1.9631), tensor(2.0574), tensor(1.9651), tensor(1.9577), tensor(2.0534), tensor(2.0518), tensor(1.9541), tensor(1.9684), tensor(2.0052), tensor(2.0529), tensor(1.8672), tensor(2.0037), tensor(1.9043), tensor(1.9523), tensor(2.0113), tensor(2.0762), tensor(2.0028), tensor(2.0036), tensor(2.2020), tensor(2.0972), tensor(2.1422), tensor(1.9260), tensor(1.6595), tensor(2.0018), tensor(1.9955), tensor(2.2663), tensor(2.0652), tensor(2.0116), tensor(1.8834), tensor(2.1099), tensor(1.9317), tensor(2.0997), tensor(1.8046), tensor(2.1067), tensor(2.0266), tensor(1.9085), tensor(2.0119), tensor(1.9780), tensor(1.9518), tensor(2.0914), tensor(2.1301), tensor(2.0984), tensor(1.8213), tensor(1.9683), tensor(1.9945), tensor(1.9541), tensor(2.0390), tensor(2.0952), tensor(2.0545), tensor(2.0428), tensor(2.0034), tensor(2.0405), tensor(2.1658), tensor(1.9162), tensor(1.8187), tensor(1.9309), tensor(2.0566), tensor(2.1379), tensor(1.9609), tensor(1.9767), tensor(2.1022), tensor(1.9582), tensor(1.9471), tensor(2.0437), tensor(2.0959), tensor(2.0089), tensor(2.0641), tensor(1.8503), tensor(1.9444), tensor(2.0772), tensor(2.1016), tensor(2.0843), tensor(2.1072), tensor(2.0477), tensor(1.8615), tensor(1.9561), tensor(2.0147), tensor(2.0451), tensor(1.8254), tensor(2.1304), tensor(2.0980), tensor(1.9775), tensor(2.1021), tensor(1.9457), tensor(2.0797), tensor(1.8258), tensor(2.1951), tensor(2.0234), tensor(1.9936), tensor(2.1725), tensor(1.8993), tensor(2.0472), tensor(1.8480), tensor(2.0565), tensor(2.0565), tensor(2.0603), tensor(2.1024), tensor(1.9213), tensor(2.0155), tensor(1.9484), tensor(2.0031), tensor(2.1194), tensor(2.0297), tensor(1.9560), tensor(2.0751), tensor(2.1230), tensor(1.9970), tensor(2.0204), tensor(2.0266), tensor(1.9309), tensor(2.0013), tensor(2.0352), tensor(1.9548), tensor(2.0010), tensor(2.1102), tensor(2.1424), tensor(2.0603), tensor(1.9988), ...
# {'mean_message_length': tensor(2.0198), 'mean_weighted_message_length': tensor(1.0606), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  206
# [tensor(2.1429), tensor(2.0387), tensor(2.0665), tensor(2.2348), tensor(2.1165), tensor(2.0631), tensor(2.0201), tensor(2.2990), tensor(2.2468), tensor(2.3168), tensor(2.1165), tensor(1.9773), tensor(2.1168), tensor(2.1499), tensor(2.0741), tensor(2.3062), tensor(2.1608), tensor(2.1868), tensor(1.9910), tensor(1.9399), tensor(2.2028), tensor(1.9126), tensor(2.3129), tensor(2.0568), tensor(2.1371), tensor(2.3689), tensor(2.0789), tensor(2.0795), tensor(1.8302), tensor(2.3054), tensor(2.1909), tensor(2.0570), tensor(2.2718), tensor(2.1556), tensor(2.0634), tensor(2.2148), tensor(2.0333), tensor(2.0375), tensor(2.1470), tensor(2.2454), tensor(2.2271), tensor(2.3164), tensor(1.9581), tensor(2.0306), tensor(2.1346), tensor(1.9669), tensor(1.9563), tensor(2.1448), tensor(2.1728), tensor(2.3624), tensor(2.1103), tensor(2.2011), tensor(2.0345), tensor(2.0773), tensor(1.9711), tensor(2.0572), tensor(2.0512), tensor(1.9229), tensor(2.0711), tensor(2.1153), tensor(2.0688), tensor(2.1128), tensor(2.0139), tensor(2.1637), tensor(2.2270), tensor(2.0573), tensor(2.1371), tensor(2.0243), tensor(1.9847), tensor(2.1659), tensor(2.0205), tensor(2.1221), tensor(2.3246), tensor(2.0418), tensor(2.1545), tensor(2.0732), tensor(2.1347), tensor(2.0196), tensor(2.1913), tensor(2.1073), tensor(1.9994), tensor(1.9957), tensor(2.0213), tensor(2.1251), tensor(2.1124), tensor(2.1344), tensor(2.1296), tensor(2.1513), tensor(2.0375), tensor(2.1137), tensor(1.9957), tensor(1.9214), tensor(2.2313), tensor(2.1256), tensor(2.1097), tensor(1.9452), tensor(2.0757), tensor(2.0567), tensor(2.3091), tensor(2.0833), tensor(1.9371), tensor(2.1953), tensor(2.2138), tensor(2.1300), tensor(2.0276), tensor(2.0217), tensor(2.0017), tensor(2.1160), tensor(2.2381), tensor(1.9546), tensor(1.9597), tensor(2.1756), tensor(2.2461), tensor(1.9668), tensor(1.9340), tensor(1.9732), tensor(1.9508), tensor(2.1679), tensor(2.1226), tensor(2.0523), tensor(1.9008), tensor(2.3770), tensor(2.1232), tensor(2.2000), tensor(2.1777), tensor(2.1535), tensor(2.0168), tensor(2.2085), tensor(2.3018), tensor(2.1183), tensor(2.1669), tensor(2.0797), tensor(2.0771), tensor(2.0558), tensor(2.0842), tensor(2.2861), tensor(1.9065), tensor(1.9035), tensor(2.2225), tensor(1.9493), tensor(2.2125), tensor(2.1065), tensor(2.1030), tensor(2.1289), tensor(2.0871), tensor(2.0680), tensor(2.1433), tensor(2.1766), tensor(1.9827), tensor(2.0215), tensor(2.1767), tensor(2.0974), tensor(2.2059), tensor(2.0817), tensor(2.2250), tensor(2.0713), tensor(2.1199), tensor(2.0367), tensor(2.1160), tensor(2.0802), tensor(2.1862), tensor(2.1936), tensor(2.2065), tensor(2.0319), tensor(2.1990), tensor(2.2021), tensor(2.1997), tensor(2.0260), tensor(2.1069), tensor(2.0890), tensor(2.3971), tensor(2.3871), tensor(2.1695), tensor(2.0064), tensor(1.8550), tensor(1.9959), tensor(1.9739), tensor(2.2575), tensor(2.2341), tensor(2.1000), tensor(2.1433), tensor(2.1727), tensor(2.1430), tensor(2.1776), tensor(2.1922), tensor(2.0613), tensor(2.1363), tensor(2.1049), tensor(2.0689), tensor(2.1535), tensor(2.1190), tensor(1.9896), tensor(2.0309), tensor(2.1934), tensor(2.1628), tensor(2.1823), tensor(2.1381), tensor(2.1406), tensor(1.8866), tensor(2.0675), tensor(2.0519), tensor(2.0731), tensor(2.0395), tensor(2.2191), tensor(2.1174), tensor(2.0348), tensor(2.1061), tensor(2.0112), tensor(2.1285), tensor(2.0313), tensor(2.1209), tensor(1.9607), tensor(2.1918), tensor(2.1087), tensor(2.1942), tensor(2.0225), tensor(2.1674), tensor(2.0857), tensor(2.1528), tensor(2.1928), tensor(2.1521), tensor(2.1570), tensor(2.0814), tensor(1.9748), tensor(1.8761), tensor(2.0177), tensor(2.1823), tensor(2.1702), tensor(2.0779), tensor(2.0998), tensor(2.0007), tensor(2.3235), tensor(2.0953), tensor(2.1818), tensor(2.2154), tensor(2.2659), tensor(2.1692), tensor(2.1983), tensor(2.0584), tensor(2.1419), tensor(1.9972), tensor(2.1888), tensor(1.9332), tensor(2.0940), tensor(2.0896), tensor(2.0278), tensor(2.1578), tensor(2.1700), tensor(1.9400), tensor(2.0929), ...
# {'mean_message_length': tensor(2.1068), 'mean_weighted_message_length': tensor(1.0867), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  209
# [tensor(2.2426), tensor(2.2767), tensor(2.1488), tensor(2.1397), tensor(2.2777), tensor(2.0899), tensor(2.2524), tensor(2.1812), tensor(2.2194), tensor(2.1743), tensor(2.2756), tensor(2.1800), tensor(2.1318), tensor(2.2438), tensor(2.2047), tensor(2.0969), tensor(2.1692), tensor(2.0853), tensor(2.2693), tensor(2.0668), tensor(2.0421), tensor(1.9672), tensor(2.0162), tensor(2.2929), tensor(1.9921), tensor(2.2277), tensor(2.1644), tensor(2.1449), tensor(2.0484), tensor(2.0992), tensor(2.2553), tensor(1.9627), tensor(2.2803), tensor(2.1072), tensor(2.0935), tensor(2.1191), tensor(2.1407), tensor(2.1674), tensor(2.0389), tensor(1.9318), tensor(2.1105), tensor(2.1798), tensor(2.2927), tensor(2.2524), tensor(2.1648), tensor(2.0478), tensor(2.1118), tensor(2.1982), tensor(2.1895), tensor(2.1916), tensor(2.1566), tensor(2.0658), tensor(2.2338), tensor(2.1181), tensor(2.0221), tensor(2.0869), tensor(2.2246), tensor(2.0846), tensor(2.0812), tensor(2.1642), tensor(2.1797), tensor(2.1674), tensor(2.2818), tensor(2.1239), tensor(2.0424), tensor(2.0502), tensor(2.1679), tensor(2.0661), tensor(2.1050), tensor(2.1741), tensor(2.3236), tensor(2.0874), tensor(1.9539), tensor(2.1887), tensor(2.0991), tensor(2.1820), tensor(2.0333), tensor(1.9763), tensor(2.1498), tensor(2.1339), tensor(2.2405), tensor(2.0694), tensor(2.1605), tensor(2.0157), tensor(2.0860), tensor(2.0376), tensor(2.2313), tensor(2.0916), tensor(2.1354), tensor(2.0781), tensor(2.1554), tensor(2.0374), tensor(2.0962), tensor(2.1777), tensor(2.0490), tensor(2.2851), tensor(2.2211), tensor(1.9033), tensor(2.0532), tensor(2.1588), tensor(2.0575), tensor(2.2150), tensor(2.0382), tensor(2.2948), tensor(2.2602), tensor(2.0603), tensor(2.1077), tensor(2.0628), tensor(1.9426), tensor(2.1937), tensor(2.1201), tensor(2.2077), tensor(2.1308), tensor(2.0392), tensor(2.2191), tensor(2.1906), tensor(2.2122), tensor(1.9462), tensor(2.0616), tensor(2.0671), tensor(2.2650), tensor(2.1240), tensor(2.2211), tensor(2.2558), tensor(2.3068), tensor(1.9776), tensor(2.0245), tensor(2.2401), tensor(2.2726), tensor(2.0296), tensor(2.1995), tensor(2.1890), tensor(2.1588), tensor(2.1541), tensor(2.3710), tensor(2.0376), tensor(2.0931), tensor(2.1096), tensor(1.8631), tensor(2.0386), tensor(2.0931), tensor(1.9993), tensor(2.1697), tensor(2.3009), tensor(2.4211), tensor(2.0719), tensor(2.0960), tensor(2.1875), tensor(2.1644), tensor(2.1486), tensor(2.2920), tensor(2.2159), tensor(2.0863), tensor(2.2922), tensor(2.0693), tensor(2.0962), tensor(2.0474), tensor(2.1581), tensor(2.2183), tensor(2.3286), tensor(2.0644), tensor(2.0254), tensor(2.1911), tensor(2.2144), tensor(2.1674), tensor(2.1192), tensor(2.3052), tensor(2.0395), tensor(2.2448), tensor(2.0244), tensor(2.0518), tensor(2.0541), tensor(2.1230), tensor(2.2102), tensor(2.1393), tensor(2.3773), tensor(2.2441), tensor(2.2574), tensor(2.1668), tensor(2.2482), tensor(2.0776), tensor(2.1147), tensor(2.2676), tensor(2.3170), tensor(2.1692), tensor(2.1274), tensor(2.1539), tensor(2.1494), tensor(2.1985), tensor(2.0493), tensor(2.0446), tensor(2.1993), tensor(2.1882), tensor(2.0565), tensor(2.0080), tensor(2.0944), tensor(2.1143), tensor(2.0016), tensor(2.0698), tensor(2.1432), tensor(2.1401), tensor(2.2210), tensor(2.1851), tensor(2.2194), tensor(2.1024), tensor(2.1740), tensor(2.2213), tensor(2.1328), tensor(2.0652), tensor(2.1243), tensor(2.2561), tensor(2.0733), tensor(2.1070), tensor(2.1865), tensor(1.9892), tensor(2.0913), tensor(2.0382), tensor(2.2137), tensor(2.1118), tensor(2.1230), tensor(2.0757), tensor(2.2988), tensor(1.9529), tensor(2.1253), tensor(2.1317), tensor(1.9482), tensor(2.1586), tensor(2.1514), tensor(2.0498), tensor(2.2398), tensor(2.1150), tensor(1.9379), tensor(1.9461), tensor(2.0762), tensor(2.2008), tensor(2.0941), tensor(2.0312), tensor(2.0612), tensor(2.0111), tensor(2.2387), tensor(2.0279), tensor(2.1389), tensor(2.0985), tensor(1.9590), tensor(2.2300), tensor(2.1978), tensor(2.2217), tensor(2.0268), tensor(1.9388), tensor(1.9239), ...
# {'mean_message_length': tensor(2.1388), 'mean_weighted_message_length': tensor(1.1875), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  202
# [tensor(2.0563), tensor(1.9975), tensor(2.2439), tensor(1.9449), tensor(2.1119), tensor(2.0101), tensor(2.0711), tensor(2.2354), tensor(2.0243), tensor(2.1773), tensor(2.1277), tensor(2.0466), tensor(2.0389), tensor(1.9633), tensor(2.0107), tensor(2.0650), tensor(2.1683), tensor(1.9940), tensor(2.2672), tensor(2.1901), tensor(2.2354), tensor(2.1153), tensor(1.9123), tensor(1.9972), tensor(2.0820), tensor(1.9313), tensor(2.1715), tensor(1.9960), tensor(2.0536), tensor(2.0436), tensor(1.8244), tensor(1.9459), tensor(2.1447), tensor(2.3013), tensor(2.0698), tensor(2.0329), tensor(1.8979), tensor(1.9838), tensor(2.2555), tensor(2.1234), tensor(2.0031), tensor(1.9823), tensor(1.9858), tensor(2.0414), tensor(1.9557), tensor(2.0471), tensor(2.0466), tensor(2.2307), tensor(2.1570), tensor(2.1057), tensor(1.9172), tensor(2.0869), tensor(1.8881), tensor(2.0125), tensor(1.9227), tensor(2.2233), tensor(2.1084), tensor(2.1799), tensor(2.3929), tensor(2.0923), tensor(2.3187), tensor(2.0846), tensor(1.9873), tensor(2.1523), tensor(2.1516), tensor(2.1167), tensor(2.1415), tensor(2.1465), tensor(1.8896), tensor(2.1288), tensor(2.0227), tensor(2.0960), tensor(2.0173), tensor(1.9679), tensor(1.8528), tensor(2.2020), tensor(1.9011), tensor(1.9628), tensor(1.7881), tensor(1.9770), tensor(1.7213), tensor(2.0815), tensor(2.0794), tensor(1.8818), tensor(1.8472), tensor(1.8687), tensor(1.9601), tensor(2.0362), tensor(2.2677), tensor(2.1189), tensor(2.0108), tensor(1.9512), tensor(2.1863), tensor(2.0479), tensor(2.1680), tensor(2.0864), tensor(2.0333), tensor(2.1260), tensor(1.8986), tensor(2.0536), tensor(2.2370), tensor(2.2771), tensor(1.9801), tensor(2.0513), tensor(1.9884), tensor(2.1979), tensor(1.9832), tensor(1.9165), tensor(2.1961), tensor(2.0460), tensor(1.9271), tensor(1.9255), tensor(2.1173), tensor(1.9785), tensor(2.0406), tensor(2.0962), tensor(2.2405), tensor(1.9532), tensor(2.0202), tensor(2.0361), tensor(1.8868), tensor(2.0456), tensor(2.0950), tensor(2.0874), tensor(2.2390), tensor(2.1964), tensor(2.1146), tensor(1.8684), tensor(1.9512), tensor(2.0394), tensor(2.1841), tensor(1.9597), tensor(2.0980), tensor(2.0846), tensor(1.7551), tensor(2.0110), tensor(2.0819), tensor(1.9260), tensor(2.1984), tensor(1.8408), tensor(2.0720), tensor(2.0013), tensor(2.1266), tensor(2.1958), tensor(2.0615), tensor(2.0777), tensor(2.2137), tensor(2.0723), tensor(2.1061), tensor(2.1311), tensor(2.0132), tensor(2.1553), tensor(1.8938), tensor(2.0441), tensor(1.8568), tensor(2.0116), tensor(2.1206), tensor(1.9942), tensor(2.1005), tensor(1.9237), tensor(2.0476), tensor(1.7956), tensor(2.1789), tensor(1.9101), tensor(1.8827), tensor(1.9428), tensor(2.0660), tensor(2.0869), tensor(2.2987), tensor(1.9754), tensor(1.9285), tensor(2.2567), tensor(1.9952), tensor(2.0346), tensor(1.9311), tensor(2.1976), tensor(1.9087), tensor(1.9428), tensor(2.0911), tensor(1.9577), tensor(2.2048), tensor(2.0629), tensor(2.0973), tensor(2.0408), tensor(1.9883), tensor(1.9758), tensor(1.9467), tensor(2.0437), tensor(1.9787), tensor(2.0941), tensor(2.0473), tensor(2.0987), tensor(2.2791), tensor(2.0399), tensor(2.0767), tensor(2.0933), tensor(1.9608), tensor(2.0890), tensor(1.8462), tensor(1.9743), tensor(2.1593), tensor(2.0875), tensor(2.0186), tensor(2.1506), tensor(2.1515), tensor(2.0569), tensor(2.0395), tensor(1.9614), tensor(2.2342), tensor(2.0404), tensor(1.9949), tensor(2.0985), tensor(2.0345), tensor(2.0338), tensor(2.1139), tensor(2.0947), tensor(2.1101), tensor(2.1218), tensor(2.0734), tensor(2.2972), tensor(2.0034), tensor(2.0849), tensor(2.2098), tensor(2.0310), tensor(2.0546), tensor(2.0501), tensor(2.2735), tensor(2.1266), tensor(1.9895), tensor(1.8539), tensor(2.1481), tensor(2.2023), tensor(1.8830), tensor(1.9198), tensor(2.1836), tensor(1.8893), tensor(2.0178), tensor(2.1593), tensor(1.9324), tensor(2.0391), tensor(2.2026), tensor(2.1950), tensor(2.0211), tensor(2.2220), tensor(2.0540), tensor(1.9708), tensor(1.9783), tensor(2.0600), tensor(2.2265), tensor(2.1260), ...
# {'mean_message_length': tensor(2.0495), 'mean_weighted_message_length': tensor(1.0740), 'p_zla': tensor(0., dtype=torch.float64)}
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# Num Messages:  180
# [tensor(1.8954), tensor(1.9292), tensor(2.1356), tensor(2.2036), tensor(1.9097), tensor(2.0495), tensor(2.1796), tensor(2.1416), tensor(2.0390), tensor(1.9687), tensor(1.9885), tensor(1.9163), tensor(2.0968), tensor(2.1394), tensor(2.0828), tensor(2.1481), tensor(2.0640), tensor(1.9568), tensor(1.9986), tensor(2.1972), tensor(2.0999), tensor(2.0164), tensor(1.7553), tensor(2.0801), tensor(2.2086), tensor(1.9433), tensor(2.0829), tensor(1.9325), tensor(2.0306), tensor(2.3230), tensor(1.8552), tensor(2.0285), tensor(2.0442), tensor(2.1349), tensor(2.1092), tensor(1.9577), tensor(1.9095), tensor(1.9862), tensor(2.1048), tensor(1.9571), tensor(1.9797), tensor(1.9884), tensor(2.0611), tensor(2.0267), tensor(2.0786), tensor(2.0114), tensor(1.9519), tensor(2.2992), tensor(2.0583), tensor(2.0708), tensor(1.8612), tensor(2.0404), tensor(2.0139), tensor(2.0063), tensor(1.9792), tensor(1.9739), tensor(1.9730), tensor(1.9971), tensor(1.9136), tensor(2.0907), tensor(2.0636), tensor(1.8859), tensor(1.9545), tensor(2.1423), tensor(2.0111), tensor(1.9842), tensor(2.0163), tensor(2.0069), tensor(2.0671), tensor(1.9657), tensor(1.9529), tensor(2.0269), tensor(2.1518), tensor(2.0473), tensor(1.9652), tensor(2.1588), tensor(2.0320), tensor(2.0082), tensor(1.9697), tensor(2.0236), tensor(2.0075), tensor(1.9578), tensor(2.2071), tensor(2.1843), tensor(1.9733), tensor(2.0299), tensor(2.2023), tensor(2.0299), tensor(2.2320), tensor(2.1705), tensor(1.9305), tensor(1.9853), tensor(2.0437), tensor(1.7326), tensor(1.9975), tensor(2.0238), tensor(2.2194), tensor(1.9449), tensor(2.1770), tensor(2.0020), tensor(1.9712), tensor(1.9821), tensor(1.8817), tensor(1.9811), tensor(1.9768), tensor(2.0122), tensor(2.1032), tensor(1.8866), tensor(2.2467), tensor(2.3636), tensor(1.9827), tensor(1.9385), tensor(1.9216), tensor(2.0061), tensor(1.9937), tensor(2.1852), tensor(2.0381), tensor(2.1500), tensor(2.0399), tensor(2.0343), tensor(2.0555), tensor(2.0719), tensor(1.9798), tensor(2.0980), tensor(1.9511), tensor(1.9898), tensor(2.1144), tensor(2.0603), tensor(2.1302), tensor(2.0870), tensor(2.1399), tensor(1.9119), tensor(2.0615), tensor(2.2001), tensor(1.9480), tensor(2.0607), tensor(2.2159), tensor(2.0285), tensor(2.1133), tensor(1.9473), tensor(2.1463), tensor(2.0774), tensor(2.0530), tensor(2.2424), tensor(2.1623), tensor(2.1946), tensor(2.1341), tensor(1.9398), tensor(2.0847), tensor(2.1883), tensor(1.9917), tensor(2.1137), tensor(2.0422), tensor(1.8120), tensor(2.0664), tensor(1.7144), tensor(1.9922), tensor(2.0385), tensor(2.0220), tensor(1.9112), tensor(1.9872), tensor(1.9627), tensor(2.1013), tensor(2.0097), tensor(2.0459), tensor(1.9512), tensor(2.1744), tensor(2.1069), tensor(2.1788), tensor(2.1614), tensor(1.9746), tensor(1.9765), tensor(2.0204), tensor(2.1625), tensor(2.0871), tensor(1.9967), tensor(1.9922), tensor(2.1288), tensor(2.0821), tensor(1.9130), tensor(2.0459), tensor(2.1760), tensor(2.0936), tensor(2.1181), tensor(2.0806), tensor(1.9526), tensor(2.1765), tensor(2.1040), tensor(2.1457), tensor(2.1673), tensor(2.2110), tensor(1.9864), tensor(2.3024), tensor(2.1418), tensor(2.1053), tensor(1.9897), tensor(2.0580), tensor(2.0004), tensor(2.0821), tensor(2.0947), tensor(2.2362), tensor(2.1196), tensor(2.1629), tensor(2.1411), tensor(2.0648), tensor(1.8902), tensor(2.0746), tensor(2.1004), tensor(1.7971), tensor(2.0724), tensor(2.1042), tensor(2.0022), tensor(2.0917), tensor(1.9859), tensor(1.8433), tensor(2.0039), tensor(2.0434), tensor(1.9595), tensor(2.1323), tensor(2.0836), tensor(2.0479), tensor(2.0806), tensor(2.1357), tensor(2.2751), tensor(1.9526), tensor(1.8472), tensor(1.9653), tensor(2.0202), tensor(2.1086), tensor(2.0570), tensor(2.0269), tensor(1.9372), tensor(1.9932), tensor(2.0555), tensor(1.9226), tensor(1.8753), tensor(2.0596), tensor(2.1898), tensor(2.1598), tensor(1.9919), tensor(2.0430), tensor(2.0443), tensor(2.0257), tensor(2.0026), tensor(2.0728), tensor(2.1959), tensor(1.8064), tensor(2.1152), tensor(2.0049), tensor(1.9929), ...
# {'mean_message_length': tensor(2.0389), 'mean_weighted_message_length': tensor(1.0512), 'p_zla': tensor(0., dtype=torch.float64)}

# %%
# standard agent
for d in range(len(datasets)):
    
    
    for run in range(5):

        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/' 
        interaction = load_interaction(paths[d],"standard",run,n_epochs)

        scores = ZLA_significance_score(interaction,num_permutations=1000,remove_after_eos=True)

        if pickle_data:
            pickle.dump(scores, open(path_to_run + 'ZLA_significance.pkl', 'wb'))
scores
# Out:
# results/(3,4)_game_size_10_vsf_3//standard/0/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//standard/1/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//standard/2/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//standard/3/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//standard/4/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//standard/0/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//standard/1/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//standard/2/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//standard/3/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//standard/4/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//standard/0/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//standard/1/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//standard/2/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//standard/3/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//standard/4/interactions/train/epoch_300/interaction_gpu0
# {'mean_message_length': tensor(4.),
#  'mean_weighted_message_length': tensor(4.),
#  'p_zla': tensor(1.)}

# %% [markdown]
# ## Symbol Informativeness

# %%
# Test if change of two unimportant values, without changing the actual symbol has an effect
interaction = load_interaction(paths[0],setting,0,n_epochs)
attributes = n_attributes[0]
values = n_values[0]
listener,_,_ = load_listener(paths[0],setting,0,attributes, values,context_unaware)
eos_token = 0.0

# symbol informativeness
messages = interaction.message
num_messages, message_length, vocab_size = messages.shape

# values to be switched
max_values, original_messages = messages.max(dim=-1)

eos_mask_total = eos_token != original_messages

# only values before eos, to switch
eos_excluded_cumulative = torch.cat([ eos_mask_total[:,:i+1].sum(dim=1).unsqueeze(1) == i+1 for i in range(message_length) ],dim=1)

# until eos, evaluating changes
eos_included_cumualtive = torch.cat([torch.ones_like(eos_excluded_cumulative[:,-1]).unsqueeze(1).bool(), eos_excluded_cumulative[:,:-1]],dim=1)

# Prediction for original messages, exclude prediction for values after eos
prediction = (listener(messages,interaction.receiver_input) > 0).float()
empty_prediction = torch.zeros_like(prediction)
prediction = torch.where(eos_included_cumualtive.unsqueeze(-1),prediction,empty_prediction)

Lambda_m_k_list = []

for i in range(message_length-1): # index = -1 is always eos and not changed. 

    # pick random new symbol index to switch with
    switch_index = torch.randint(1,vocab_size,(num_messages,))

    # make sure switch_index != original_messages
    same_indices = (switch_index == original_messages[:,i])
    while same_indices.any():
        switch_index[same_indices] = torch.randint(1, vocab_size, (same_indices.sum().item(),))
        same_indices = (switch_index == original_messages[:,i])

    # values to switch with
    new_value = torch.gather(messages[:,i,:],-1,switch_index.unsqueeze(-1)).squeeze()

    # pick random new symbol index to switch with #2 for switching in background
    switch_index2 = torch.randint(1,vocab_size,(num_messages,))

    # make sure switch_index != original_messages and != switch_index
    same_indices = (switch_index2 == original_messages[:,i]) + (switch_index2 == switch_index)
    while same_indices.any():
        switch_index2[same_indices] = torch.randint(1, vocab_size, (same_indices.sum().item(),))
        same_indices = (switch_index2 == original_messages[:,i]) + (switch_index2 == switch_index)

    # values to switch with
    new_value2 = torch.gather(messages[:,i,:],-1,switch_index2.unsqueeze(-1)).squeeze()

    messages_manipulated = messages.clone()

    # if eosed, take old value in so no switch (with 2 not max)
    new_value_without_eos = torch.where(eos_excluded_cumulative[:,i].squeeze(), new_value,new_value2)
    new_value2_without_eos = torch.where(eos_excluded_cumulative[:,i].squeeze(), new_value2,new_value)

    # switch value i of all messages to new symbol # not max
    messages_manipulated[:,i].scatter_(-1,switch_index2.unsqueeze(-1),new_value_without_eos.unsqueeze(-1))
    messages_manipulated[:,i].scatter_(-1,switch_index.unsqueeze(-1),new_value2_without_eos.unsqueeze(-1))

    prediction_manipulated = (listener(messages_manipulated,interaction.receiver_input) > 0).float() # bigger 0 means thinks its a concept object
    prediction_manipulated = torch.where(eos_included_cumualtive.unsqueeze(-1),prediction_manipulated,empty_prediction)

    # compare whether same classification not same values
    # only include predictions for symbols that are not eosed yet.
    Lambda_m_k_position = (prediction != prediction_manipulated).sum(dim=(1,2)).unsqueeze(1).bool() # (num_messages, 1 )
    Lambda_m_k_list.append(Lambda_m_k_position)

Lambda_m_k = torch.cat(Lambda_m_k_list,dim=1)
eos_mask = eos_excluded_cumulative[:,:-1] # both should be the same shape

scores = information_analysis(listener,interaction,eos_token=0.0)
print("\n Max (normal) switch: ", scores)

return_dict = {
    "positional_encoding" : positional_encoding(Lambda_m_k, eos_mask),
    "effective_length" : effective_length(Lambda_m_k, eos_mask),
    "information_density" : information_density(Lambda_m_k,eos_mask)
}
print("\nUnimportant switch: ", return_dict)
print("Number of important symbols: ", Lambda_m_k.sum())
# Out:
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
#
#  Max (normal) switch:  {'positional_encoding': tensor([0.9693, 0.9582, 0.7778]), 'effective_length': tensor(1.0817), 'information_density': tensor(0.9660)}
#
# Unimportant switch:  {'positional_encoding': tensor([0.0489, 0.0070, 0.0000]), 'effective_length': tensor(0.0443), 'information_density': tensor(0.0395)}
# Number of important symbols:  tensor(78)

# %%
# normal symbol information analysis
for d in range(len(datasets)):
    
    for run in range(5):

        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/' 
        interaction = load_interaction(paths[d],setting,run,n_epochs)

        attributes = n_attributes[d]
        values = n_values[d]

        listener,_,_ = load_listener(paths[d],setting,run,attributes, values,context_unaware)

        scores = information_analysis(listener,interaction,eos_token=0.0)

        if pickle_data:
            pickle.dump(scores, open(path_to_run + 'symbol_informativeness.pkl', 'wb'))

scores
# Out:
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/0/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/1/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/2/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/3/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# {'positional_encoding': tensor([0.9172, 0.9225, 0.8148, 1.0000]),
#  'effective_length': tensor(0.9650),
#  'information_density': tensor(0.9180)}

# %%
# normal symbol information analysis for standard agent (control)
for d in range(len(datasets)):
    
    for run in range(5):

        path_to_run = paths[d] + "standard" +'/' + str(run) + '/' 
        interaction = load_interaction(paths[d],"standard",run,n_epochs)

        attributes = n_attributes[d]
        values = n_values[d]

        listener,_,_ = load_listener(paths[d],"standard",run,attributes, values,False)

        scores = information_analysis(listener,interaction,eos_token=0.0)

        if pickle_data:
            pickle.dump(scores, open(path_to_run + 'symbol_informativeness.pkl', 'wb'))
scores
# Out:
# results/(3,4)_game_size_10_vsf_3//standard/0/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//standard/1/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//standard/2/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//standard/3/interactions/train/epoch_300/interaction_gpu0
# results/(3,4)_game_size_10_vsf_3//standard/4/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//standard/0/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//standard/1/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//standard/2/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//standard/3/interactions/train/epoch_300/interaction_gpu0
# results/(3,8)_game_size_10_vsf_3//standard/4/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//standard/0/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//standard/1/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//standard/2/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//standard/3/interactions/train/epoch_300/interaction_gpu0
# results/(4,4)_game_size_10_vsf_3//standard/4/interactions/train/epoch_300/interaction_gpu0
# {'positional_encoding': tensor([0.9980, 0.9749, 0.8595, 0.7500]),
#  'effective_length': tensor(3.5824),
#  'information_density': tensor(0.8956)}

# %%
# for debugging only, calculate probability mass
interaction = load_interaction(paths[d],setting,run,n_epochs)
listener,_,_ = load_listener(paths[d],setting,run,attributes, values,context_unaware)
message = interaction.message
receiver_output = listener(message,interaction.receiver_input)

impatience = True

not_eosed_before = torch.ones(receiver_output.size(0))
expected_length = 0.0 # final includes eos here
z = 0.0

for step in range(receiver_output.size(1)):
    eos_mask = message[:, step, 0]  # always eos == 0
    if impatience:
        add_mask = not_eosed_before
    else:
        add_mask = eos_mask * not_eosed_before
    z += add_mask
    expected_length += add_mask.detach() * (1.0 + step)
    print(not_eosed_before)
    not_eosed_before = not_eosed_before * (1.0 - eos_mask)

expected_length += (step + 1) * not_eosed_before
z += not_eosed_before
assert z.allclose(
            z
        ), f"lost probability mass, {z.min()}, {z.max()}"
z
# Out:
# results/(3,4)_game_size_10_vsf_3//lazimpa_context_aware/4/interactions/train/epoch_300/interaction_gpu0
# tensor([1., 1., 1.,  ..., 1., 1., 1.])
# tensor([1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000])
# tensor([1.7881e-05, 1.1921e-06, 0.0000e+00,  ..., 8.3447e-07, 2.2888e-04,
#         1.9958e-03])
# tensor([1.7878e-05, 1.1911e-06, 0.0000e+00,  ..., 6.4132e-07, 2.2738e-04,
#         1.9958e-03])
# tensor([2.0000, 2.0000, 2.0000,  ..., 2.0000, 2.0005, 2.0040])

# %% [markdown]
# ## Data analysis for attribute visualization

# %%
#TODO

# %% [markdown]
# ##  compositionality scores: topsim, posdis, bosdis

# %% [markdown]
# ### topsim

# %%
# topsim
# although topsim values are stored throughout training if callbacks are verbose, we reevaluate the
# final topsim scores with more data points 

samples = 1000 # maybe shuffle from these because otherwise I just take the first 5,000 (which might not be the best)
for d, dataset in enumerate(datasets):
    
    dim = [n_values[d]]*n_attributes[d]
    
    for run in range(5):
        print("dataset", dataset, "run", run)
        
        topsim_final = {}
        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/'
        path_to_interaction_train = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        path_to_interaction_val = (path_to_run + 'interactions/validation/epoch_' + str(n_epochs) + '/interaction_gpu0')
        
        TOPSIM = TopographicSimilarityConceptLevel(dim, is_gumbel=True)
        
        for mode in ['train', 'val']:

            if mode == 'train':
                interaction = torch.load(path_to_interaction_train)
            elif mode == 'val':
                interaction = torch.load(path_to_interaction_val)
                
                  
            messages = interaction.message.argmax(dim=-1)
            sender_input = interaction.sender_input
            n_targets = int(sender_input.shape[1]/2)
            # get target objects and fixed vectors to re-construct concepts
            target_objects = sender_input[:, :n_targets]
            target_objects = k_hot_to_attributes(target_objects, n_values[d])
            # concepts are defined by a list of target objects (here one sampled target object) and a fixed vector
            (objects, fixed) = retrieve_concepts_sampling(target_objects)
            # add one such that zero becomes an empty attribute for the calculation (_)
            objects = objects + 1
            concepts = torch.from_numpy(objects * (np.array(fixed)))
            specific_idx = np.where(np.sum(fixed, axis=1)==n_attributes[d])[0]
            messages_specific = messages[specific_idx]
            concepts_specific = concepts[specific_idx]
            
            generic_idx = np.where(np.sum(fixed, axis=1)==1)[0]
            messages_generic = messages[generic_idx]
            concepts_generic = concepts[generic_idx]

            messages = [msg.tolist() for msg in messages]
            messages_specific = [msg.tolist() for msg in messages_specific]
            messages_generic = [msg.tolist() for msg in messages_generic]

            encoded_input = encode_target_concepts_for_topsim(sender_input)
            # randomly take samples when more than 5000 samples are available
            # if len(encoded_input) > samples: 
            #     print("sampling")
            #     sample_indices = random.sample(range(len(encoded_input)), samples)
            #     sampled_input = [encoded_input[i] for i in sample_indices]
            #     sampled_messages = [messages[i] for i in sample_indices]
            #     print("start computing")
            #     print(len(sampled_input), len(sampled_input[0]), len(sampled_input[0][0]))
            #     topsim = TOPSIM.compute_topsim(sampled_input, sampled_messages)
            # else:
            topsim = TOPSIM.compute_topsim(encoded_input[0:samples], messages[0:samples]) # default: hausdorff distance for concepts, edit distance for messages
            # if len(concepts_specific) > samples:
            #     print("sampling specific")
            #     sample_indices_specific = random.sample(range(len(concepts_specific)), samples)
            #     sampled_input_specific = [concepts_specific[i] for i in sample_indices_specific]
            #     sampled_messages_specific = [messages_specific[i] for i in sample_indices_specific]
            #     topsim_specific = TOPSIM.compute_topsim(sampled_input_specific, sampled_messages_specific, 
            #                                             meaning_distance_fn="edit")
            # else:
            topsim_specific = TOPSIM.compute_topsim(concepts_specific[0:samples], messages_specific[0:samples], 
                                                        meaning_distance_fn="edit")
            
            topsim_generic = TOPSIM.compute_topsim(concepts_generic[0:samples], messages_generic[0:samples],
                                                   meaning_distance_fn="edit")

            print('... topsim computed')

            topsim_final['topsim_' + mode] = topsim
            topsim_final['topsim_specific_' + mode] = topsim_specific
            topsim_final['topsim_generic_' + mode] = topsim_generic
    
        if pickle_data:
            pickle.dump(topsim_final, open(path_to_run +  "topsim_final.pkl", "wb" ) )
        print(topsim_final)
# Out:
# dataset (3,4) run 0
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.18796677386952407, 'topsim_specific_train': 0.22305092596961135, 'topsim_generic_train': 0.3070700850045201, 'topsim_val': 0.2242431716732342, 'topsim_specific_val': 0.27226513675041514, 'topsim_generic_val': 0.3135998635217133}
# dataset (3,4) run 1
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.19731779138649497, 'topsim_specific_train': 0.20511581489576586, 'topsim_generic_train': 0.38178840983386914, 'topsim_val': 0.23233058627732506, 'topsim_specific_val': 0.2619156159893861, 'topsim_generic_val': 0.2865912960301693}
# dataset (3,4) run 2
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.2377904370201794, 'topsim_specific_train': 0.23453927759987075, 'topsim_generic_train': 0.3289677946979688, 'topsim_val': 0.25799971965965923, 'topsim_specific_val': 0.2647576115695098, 'topsim_generic_val': 0.1538921964646194}
# dataset (3,4) run 3
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.17464296431309767, 'topsim_specific_train': 0.18883721859686134, 'topsim_generic_train': 0.26879750639425487, 'topsim_val': 0.2529031028693822, 'topsim_specific_val': 0.2491444499601285, 'topsim_generic_val': 0.3341198730145754}
# dataset (3,4) run 4
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.17442194163121866, 'topsim_specific_train': 0.1638722663276361, 'topsim_generic_train': 0.6047689500252655, 'topsim_val': 0.21451656516607756, 'topsim_specific_val': 0.18750319635139684, 'topsim_generic_val': 0.38136687953570425}
# dataset (3,8) run 0
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.09408622486415565, 'topsim_specific_train': 0.10205978547362501, 'topsim_generic_train': 0.3814775375551397, 'topsim_val': 0.11009925865924244, 'topsim_specific_val': 0.11696775430890656, 'topsim_generic_val': 0.3197844315184598}
# dataset (3,8) run 1
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.09927758771554963, 'topsim_specific_train': 0.10520717669293123, 'topsim_generic_train': 0.17225845701412054, 'topsim_val': 0.13206226084031988, 'topsim_specific_val': 0.12166812756396624, 'topsim_generic_val': 0.16895025455367335}
# dataset (3,8) run 2
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.09627178759894484, 'topsim_specific_train': 0.09789994471882488, 'topsim_generic_train': 0.2352529452960632, 'topsim_val': 0.09655873140714107, 'topsim_specific_val': 0.10284938575744229, 'topsim_generic_val': 0.2092267094737035}
# dataset (3,8) run 3
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.0856889648752605, 'topsim_specific_train': 0.11835502599066382, 'topsim_generic_train': 0.29044127731786556, 'topsim_val': 0.08662683102584813, 'topsim_specific_val': 0.11677176649801926, 'topsim_generic_val': 0.2267071492635142}
# dataset (3,8) run 4
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.0945345352121572, 'topsim_specific_train': 0.10564307413519858, 'topsim_generic_train': 0.4020218979344178, 'topsim_val': 0.11098637734597117, 'topsim_specific_val': 0.11678524284435551, 'topsim_generic_val': 0.2971597129765212}
# dataset (4,4) run 0
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.14217166043406404, 'topsim_specific_train': 0.12591758368904366, 'topsim_generic_train': 0.33515532751920235, 'topsim_val': 0.2136907653322349, 'topsim_specific_val': 0.20503491205505817, 'topsim_generic_val': 0.3822843195057136}
# dataset (4,4) run 1
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.15098355825566223, 'topsim_specific_train': 0.14149503268380623, 'topsim_generic_train': 0.3707222392328253, 'topsim_val': 0.2172530746788787, 'topsim_specific_val': 0.23268053843177883, 'topsim_generic_val': 0.2290906546037256}
# dataset (4,4) run 2
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.13099895376420695, 'topsim_specific_train': 0.15715079362792028, 'topsim_generic_train': 0.38760893833285526, 'topsim_val': 0.1967008806073326, 'topsim_specific_val': 0.1926141917845076, 'topsim_generic_val': 0.24388052861386791}
# dataset (4,4) run 3
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.14011612801802698, 'topsim_specific_train': 0.1404961389015337, 'topsim_generic_train': 0.2557179251941211, 'topsim_val': 0.2298565609372789, 'topsim_specific_val': 0.2315631201572879, 'topsim_generic_val': 0.1371129518405933}
# dataset (4,4) run 4
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.1246473307062682, 'topsim_specific_train': 0.09870724807018684, 'topsim_generic_train': 0.3171348483456151, 'topsim_val': 0.16344395061754957, 'topsim_specific_val': 0.15735146213929216, 'topsim_generic_val': 0.2767749858942601}

# %% [markdown]
# #### Topsim over time

# %%
for d, dataset in enumerate(datasets):
    
    for run in range(5):
        print("dataset", dataset, "run", run)
        
        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/'
        path_to_interaction_train = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        path_to_interaction_val = (path_to_run + 'interactions/validation/epoch_' + str(n_epochs) + '/interaction_gpu0')
        
        for mode in ['train', 'val']:

            if mode == 'train':
                interaction = torch.load(path_to_interaction_train)
            elif mode == 'val':
                interaction = torch.load(path_to_interaction_val)

        messages = interaction.message.argmax(dim=-1)
        sender_input = interaction.sender_input
        messages = [msg.tolist() for msg in messages]
        encoded_input = encode_target_concepts_for_topsim(sender_input)
        dim = [n_values[0]] * n_attributes[0]
        TOPSIM = TopographicSimilarityConceptLevel(dim, is_gumbel=True)
        
        samples = 1000
        num_batches = len(messages) // samples + (len(messages) % samples > 0)
        topsim_over_time = []
        
        for i in range(num_batches):
            messages_batch = messages[i * samples:(i + 1) * samples]
            topsim = TOPSIM.compute_topsim(encoded_input[i * samples:(i + 1) * samples], messages_batch)
            topsim_over_time.append(topsim)
            
        if pickle_data:
            pickle.dump(topsim_over_time, open(path_to_run +  "topsim_over_time.pkl", "wb" ) )
# Out:
# dataset (3,4) run 0
# dataset (3,4) run 1
# dataset (3,4) run 2
# dataset (3,4) run 3
# dataset (3,4) run 4
# dataset (3,8) run 0
# dataset (3,8) run 1
# dataset (3,8) run 2
# dataset (3,8) run 3
# dataset (3,8) run 4
# dataset (4,4) run 0
# dataset (4,4) run 1
# dataset (4,4) run 2
# dataset (4,4) run 3
# dataset (4,4) run 4

# %% [markdown]
# ### Posdis and Bosdis

# %%
# use Disent callback from egg

for d in range(len(datasets)): 
    
    path = paths[d]
    dim = [n_values[d]] * n_attributes[d]
    n_features = n_attributes[d] * n_values[d]
    vs_factor = int(path[-2])
    vocab_size = (n_values[d] + 1) * vs_factor + 1
    
    print("data set", dim)
    
    for run in range(5):
        
        posdis_bosdis = {}
    
        path_to_run = paths[d] + '/' + str(setting) +'/' + str(run) + '/'
        path_to_interaction_train = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        interaction = torch.load(path_to_interaction_train)
        
        messages = interaction.message.argmax(dim=-1)
        sender_input = interaction.sender_input
        n_targets = int(sender_input.shape[1]/2)
        # get target objects and fixed vectors to re-construct concepts
        target_objects = sender_input[:, :n_targets]
        target_objects = k_hot_to_attributes(target_objects, n_values[d])
        # concepts are defined by a list of target objects (here one sampled target object) and a fixed vector
        (objects, fixed) = retrieve_concepts_sampling(target_objects)
        # add one such that zero becomes an empty attribute for the calculation (_)
        objects = objects + 1
        concepts = torch.from_numpy(objects * (np.array(fixed)))

        # concrete/specific concepts: where all attributes are fixed
        concepts_specific = torch.tensor(
            objects[torch.sum(torch.from_numpy(fixed), dim=1) == n_attributes[d]])
        messages_specific = messages[torch.sum(torch.from_numpy(fixed), dim=1) == n_attributes[d]]

        # generic concepts: where only one attribute is fixed
        concepts_generic = torch.tensor(
            objects[torch.sum(torch.from_numpy(fixed), dim=1) == 1])
        messages_generic = messages[torch.sum(torch.from_numpy(fixed), dim=1) == 1]
        
        posdis_specific = Disent.posdis(concepts_specific, messages_specific)
        bosdis_specific = Disent.bosdis(concepts_specific, messages_specific, vocab_size)

        posdis_generic = Disent.posdis(concepts_generic, messages_generic)
        bosdis_generic = Disent.bosdis(concepts_generic, messages_generic, vocab_size)
        
        posdis = Disent.posdis(torch.from_numpy(objects), messages)
        bosdis = Disent.bosdis(torch.from_numpy(objects), messages, vocab_size)
        
        posdis_bosdis['posdis_specific'] = posdis_specific
        posdis_bosdis['bosdis_specific'] = bosdis_specific
        posdis_bosdis['posdis_generic'] = posdis_generic
        posdis_bosdis['bosdis_generic'] = bosdis_generic
        posdis_bosdis['posdis'] = posdis
        posdis_bosdis['bosdis'] = bosdis

        print(posdis_bosdis)
    
        if pickle_data:
            pickle.dump(posdis_bosdis, open(path_to_run + "posdis_bosdis.pkl", "wb" ) )
# Out:
# data set [4, 4, 4]
# {'posdis_specific': 0.04806709662079811, 'bosdis_specific': 0.24908646941184998, 'posdis_generic': 0.07418928295373917, 'bosdis_generic': 0.3077387809753418, 'posdis': 0.04486815631389618, 'bosdis': 0.2588385343551636}
# {'posdis_specific': 0.05818255618214607, 'bosdis_specific': 0.20112445950508118, 'posdis_generic': 0.10012919455766678, 'bosdis_generic': 0.32522934675216675, 'posdis': 0.03896735981106758, 'bosdis': 0.20639926195144653}
# {'posdis_specific': 0.05935806408524513, 'bosdis_specific': 0.2289711833000183, 'posdis_generic': 0.04975811019539833, 'bosdis_generic': 0.22203244268894196, 'posdis': 0.040026601403951645, 'bosdis': 0.22377990186214447}
# {'posdis_specific': 0.06014275923371315, 'bosdis_specific': 0.30911585688591003, 'posdis_generic': 0.19710777699947357, 'bosdis_generic': 0.25875261425971985, 'posdis': 0.0431329719722271, 'bosdis': 0.30128157138824463}
# {'posdis_specific': 0.06762847304344177, 'bosdis_specific': 0.2637227475643158, 'posdis_generic': 0.1532263606786728, 'bosdis_generic': 0.2642113268375397, 'posdis': 0.07538603991270065, 'bosdis': 0.26492154598236084}
# data set [8, 8, 8]
# {'posdis_specific': 0.04069240391254425, 'bosdis_specific': 0.1851859986782074, 'posdis_generic': 0.02718394435942173, 'bosdis_generic': 0.29024362564086914, 'posdis': 0.04009595513343811, 'bosdis': 0.18857862055301666}
# {'posdis_specific': 0.04350518807768822, 'bosdis_specific': 0.20536062121391296, 'posdis_generic': 0.020340433344244957, 'bosdis_generic': 0.2739049792289734, 'posdis': 0.030999163165688515, 'bosdis': 0.20685537159442902}
# {'posdis_specific': 0.04969507455825806, 'bosdis_specific': 0.12943284213542938, 'posdis_generic': 0.0333930104970932, 'bosdis_generic': 0.20779070258140564, 'posdis': 0.04839161038398743, 'bosdis': 0.13922536373138428}
# {'posdis_specific': 0.025246843695640564, 'bosdis_specific': 0.10552417486906052, 'posdis_generic': 0.032755717635154724, 'bosdis_generic': 0.2082243114709854, 'posdis': 0.021885579451918602, 'bosdis': 0.11873717606067657}
# {'posdis_specific': 0.05010226368904114, 'bosdis_specific': 0.20279161632061005, 'posdis_generic': 0.04462899640202522, 'bosdis_generic': 0.32045111060142517, 'posdis': 0.06121060252189636, 'bosdis': 0.21089687943458557}
# data set [4, 4, 4, 4]
# {'posdis_specific': 0.02617955580353737, 'bosdis_specific': 0.42350658774375916, 'posdis_generic': 0.04773803800344467, 'bosdis_generic': 0.233015775680542, 'posdis': 0.02747374027967453, 'bosdis': 0.4049025774002075}
# {'posdis_specific': 0.04328310117125511, 'bosdis_specific': 0.38225239515304565, 'posdis_generic': 0.023821106180548668, 'bosdis_generic': 0.1480262726545334, 'posdis': 0.037911027669906616, 'bosdis': 0.35238131880760193}
# {'posdis_specific': 0.03206302970647812, 'bosdis_specific': 0.29722878336906433, 'posdis_generic': 0.029602091759443283, 'bosdis_generic': 0.1925947368144989, 'posdis': 0.027937673032283783, 'bosdis': 0.28211909532546997}
# {'posdis_specific': 0.01554359681904316, 'bosdis_specific': 0.37755265831947327, 'posdis_generic': 0.038022730499506, 'bosdis_generic': 0.2453024983406067, 'posdis': 0.0209474079310894, 'bosdis': 0.3619994521141052}
# {'posdis_specific': 0.02464435249567032, 'bosdis_specific': 0.3407096564769745, 'posdis_generic': 0.056199122220277786, 'bosdis_generic': 0.23916660249233246, 'posdis': 0.02287883125245571, 'bosdis': 0.33810997009277344}
