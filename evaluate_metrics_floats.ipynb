# %%
import pickle
from utils.analysis_from_interaction import *
from egg.core.language_analysis import Disent
from language_analysis_local import TopographicSimilarityConceptLevel, encode_target_concepts_for_topsim

# %% [markdown]
# # calculate metrics from stored interactions

# %%
datasets = ('(3,4)', '(3,8)', '(3,16)', '(4,4)', '(4,8)', '(5,4)')
n_attributes = (3, 3, 3, 4, 4, 5)
n_values = (4, 8, 16, 4, 8, 4)
n_epochs = 300
paths = [f'results/vague_ds_results/{d}_game_size_10_vsf_3/' for d in datasets]

# %%
context_unaware = False # whether original or context_unaware simulations are evaluated
length_cost = False
if context_unaware:
    setting = 'context_unaware'
elif length_cost:
    setting = 'length_cost_001'
else:
    setting = 'standard'

# %% [markdown]
# ### entropy scores: MI, effectiveness, efficiency

# %%
for d in range(len(datasets)):
    for run in range(5):

        path_to_run = paths[d] + '/' + str(setting) +'/' + str(run) + '/' 
        print(path_to_run)
        path_to_interaction = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        interaction = torch.load(path_to_interaction)

        attributes = n_attributes[d]
        values = n_values[d]
        scores = information_scores(interaction, attributes, values, normalizer="arithmetic")

        pickle.dump(scores, open(path_to_run + 'entropy_scores.pkl', 'wb'))
# Out:
# results/vague_ds_results/(3,4)_game_size_10_vsf_3//standard/0/
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:315: RuntimeWarning: invalid value encountered in divide
#   (m_entropy_concept_x_context + c_entropy_concept_x_context - joint_entropy_concept_x_context)
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:324: RuntimeWarning: invalid value encountered in divide
#   normalized_effectiveness_conc_x_cont = ((joint_entropy_concept_x_context - m_entropy_concept_x_context)
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:331: RuntimeWarning: invalid value encountered in divide
#   normalized_consistency_conc_x_cont = (
# results/vague_ds_results/(3,4)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(3,4)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(3,4)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(3,4)_game_size_10_vsf_3//standard/4/
# results/vague_ds_results/(3,8)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(3,8)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(3,8)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(3,8)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(3,8)_game_size_10_vsf_3//standard/4/
# results/vague_ds_results/(3,16)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(3,16)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(3,16)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(3,16)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(3,16)_game_size_10_vsf_3//standard/4/
# results/vague_ds_results/(4,4)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(4,4)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(4,4)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(4,4)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(4,4)_game_size_10_vsf_3//standard/4/
# results/vague_ds_results/(4,8)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(4,8)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(4,8)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(4,8)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(4,8)_game_size_10_vsf_3//standard/4/
# results/vague_ds_results/(5,4)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(5,4)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(5,4)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(5,4)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(5,4)_game_size_10_vsf_3//standard/4/

# %% [markdown]
# ###  message length

# %%
# we evaluated message length per hierarchy level after training but 
# you can also use the HierarchicalMessageLength callback and store the results 
# TODO: Message length results look weird, needs to be fixed!

for d in range(len(datasets)):
    
    for run in range(5): 
        
        path_to_run = paths[d] + '/' + str(setting) +'/' + str(run) + '/'
        path_to_interaction = (path_to_run + 'interactions/train/interactions_epoch' + str(n_epochs))
        path_to_interaction = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        interaction = torch.load(path_to_interaction)

        attributes = n_attributes[d]
        values = n_values[d]
        scores = message_length_per_hierarchy_level(interaction, attributes)
        
        pickle.dump(scores, open(path_to_run + 'message_length_hierarchical.pkl', 'wb'))
# Out:
# tensor([[7, 4, 4, 0],
#         [7, 8, 7, 0],
#         [7, 1, 4, 0],
#         ...,
#         [7, 8, 7, 0],
#         [7, 7, 7, 0],
#         [6, 1, 8, 0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[7, 4, 4, 0],
#         [7, 8, 7, 0],
#         [7, 1, 4, 0],
#         ...,
#         [7, 8, 7, 0],
#         [7, 7, 7, 0],
#         [6, 1, 8, 0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 2.999]
# tensor([[11,  7, 11,  0],
#         [14,  5,  4,  0],
#         [ 5,  4, 15,  0],
#         ...,
#         [15,  4,  4,  0],
#         [11,  9, 11,  0],
#         [ 5,  8, 11,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[11,  7, 11,  0],
#         [14,  5,  4,  0],
#         [ 5,  4, 15,  0],
#         ...,
#         [15,  4,  4,  0],
#         [11,  9, 11,  0],
#         [ 5,  8, 11,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[15,  7,  8,  0],
#         [ 8,  8,  2,  0],
#         [ 9,  8, 10,  0],
#         ...,
#         [ 8,  4,  9,  0],
#         [ 4,  4,  9,  0],
#         [ 8,  8,  9,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[15,  7,  8,  0],
#         [ 8,  8,  2,  0],
#         [ 9,  8, 10,  0],
#         ...,
#         [ 8,  4,  9,  0],
#         [ 4,  4,  9,  0],
#         [ 8,  8,  9,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[ 6,  9,  9,  0],
#         [13,  7,  6,  0],
#         [ 6,  9,  6,  0],
#         ...,
#         [ 7,  7,  7,  0],
#         [ 6,  9,  6,  0],
#         [ 9,  9,  9,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[ 6,  9,  9,  0],
#         [13,  7,  6,  0],
#         [ 6,  9,  6,  0],
#         ...,
#         [ 7,  7,  7,  0],
#         [ 6,  9,  6,  0],
#         [ 9,  9,  9,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[ 4,  2,  4,  0],
#         [ 4,  4,  8,  0],
#         [12,  2, 15,  0],
#         ...,
#         [ 4,  4,  4,  0],
#         [13, 13, 13,  0],
#         [ 4,  4,  4,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[ 4,  2,  4,  0],
#         [ 4,  4,  8,  0],
#         [12,  2, 15,  0],
#         ...,
#         [ 4,  4,  4,  0],
#         [13, 13, 13,  0],
#         [ 4,  4,  4,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[ 2, 14, 14,  0],
#         [ 2,  8,  5,  0],
#         [19, 25,  1,  0],
#         ...,
#         [16,  2, 25,  0],
#         [11,  5, 14,  0],
#         [ 5,  5, 19,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[ 2, 14, 14,  0],
#         [ 2,  8,  5,  0],
#         [19, 25,  1,  0],
#         ...,
#         [16,  2, 25,  0],
#         [11,  5, 14,  0],
#         [ 5,  5, 19,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[ 1,  1,  1,  0],
#         [27, 27,  1,  0],
#         [ 1,  6, 26,  0],
#         ...,
#         [27,  1,  4,  0],
#         [15, 13, 23,  0],
#         [10, 15, 27,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[ 1,  1,  1,  0],
#         [27, 27,  1,  0],
#         [ 1,  6, 26,  0],
#         ...,
#         [27,  1,  4,  0],
#         [15, 13, 23,  0],
#         [10, 15, 27,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[ 6, 24,  6,  0],
#         [15, 15, 19,  0],
#         [11,  6, 24,  0],
#         ...,
#         [16,  2, 11,  0],
#         [ 6, 25, 22,  0],
#         [ 3,  4, 21,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[ 6, 24,  6,  0],
#         [15, 15, 19,  0],
#         [11,  6, 24,  0],
#         ...,
#         [16,  2, 11,  0],
#         [ 6, 25, 22,  0],
#         [ 3,  4, 21,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[25,  7, 11,  0],
#         [ 5,  5,  3,  0],
#         [16, 16, 22,  0],
#         ...,
#         [25,  1, 18,  0],
#         [16, 16, 16,  0],
#         [27, 15,  8,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[25,  7, 11,  0],
#         [ 5,  5,  3,  0],
#         [16, 16, 22,  0],
#         ...,
#         [25,  1, 18,  0],
#         [16, 16, 16,  0],
#         [27, 15,  8,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[24,  8,  3,  0],
#         [16,  5, 22,  0],
#         [13, 13, 20,  0],
#         ...,
#         [16, 22, 22,  0],
#         [16, 27, 16,  0],
#         [ 5, 13, 21,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[24,  8,  3,  0],
#         [16,  5, 22,  0],
#         [13, 13, 20,  0],
#         ...,
#         [16, 22, 22,  0],
#         [16, 27, 16,  0],
#         [ 5, 13, 21,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[ 2, 31, 22,  0],
#         [25, 30, 30,  0],
#         [15, 48, 50,  0],
#         ...,
#         [ 9,  9, 45,  0],
#         [25, 30,  2,  0],
#         [ 2,  2, 50,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[ 2, 31, 22,  0],
#         [25, 30, 30,  0],
#         [15, 48, 50,  0],
#         ...,
#         [ 9,  9, 45,  0],
#         [25, 30,  2,  0],
#         [ 2,  2, 50,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[36, 40, 42,  0],
#         [20, 16, 47,  0],
#         [25, 11, 11,  0],
#         ...,
#         [36, 40, 47,  0],
#         [49, 47, 28,  0],
#         [13, 13, 23,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[36, 40, 42,  0],
#         [20, 16, 47,  0],
#         [25, 11, 11,  0],
#         ...,
#         [36, 40, 47,  0],
#         [49, 47, 28,  0],
#         [13, 13, 23,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[36, 36, 46,  0],
#         [ 8, 45, 45,  0],
#         [ 9, 14,  5,  0],
#         ...,
#         [ 7, 35, 41,  0],
#         [14, 14, 41,  0],
#         [11, 11, 39,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[36, 36, 46,  0],
#         [ 8, 45, 45,  0],
#         [ 9, 14,  5,  0],
#         ...,
#         [ 7, 35, 41,  0],
#         [14, 14, 41,  0],
#         [11, 11, 39,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[37, 18, 18,  0],
#         [20,  5,  2,  0],
#         [37, 42, 38,  0],
#         ...,
#         [20, 20, 20,  0],
#         [32, 50, 43,  0],
#         [51,  2,  2,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[37, 18, 18,  0],
#         [20,  5,  2,  0],
#         [37, 42, 38,  0],
#         ...,
#         [20, 20, 20,  0],
#         [32, 50, 43,  0],
#         [51,  2,  2,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[22, 26, 18,  0],
#         [24, 27,  4,  0],
#         [16, 35, 35,  0],
#         ...,
#         [16, 41, 49,  0],
#         [22,  5, 18,  0],
#         [42, 15, 26,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([3, 3, 3,  ..., 3, 3, 3])
# tensor([[22, 26, 18,  0],
#         [24, 27,  4,  0],
#         [16, 35, 35,  0],
#         ...,
#         [16, 41, 49,  0],
#         [22,  5, 18,  0],
#         [42, 15, 26,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [3.0, 3.0, 3.0]
# tensor([[13,  9, 15, 13,  0],
#         [ 1, 13, 11, 13,  0],
#         [13,  9,  9,  8,  0],
#         ...,
#         [ 2,  1,  1, 11,  0],
#         [ 7,  6,  6,  1,  0],
#         [ 4,  1,  8, 11,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([4, 4, 4,  ..., 4, 4, 4])
# tensor([[13,  9, 15, 13,  0],
#         [ 1, 13, 11, 13,  0],
#         [13,  9,  9,  8,  0],
#         ...,
#         [ 2,  1,  1, 11,  0],
#         [ 7,  6,  6,  1,  0],
#         [ 4,  1,  8, 11,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [4.0, 4.0, 4.0, 4.0]
# tensor([[12, 12,  8,  1,  0],
#         [ 1,  5,  3, 15,  0],
#         [11, 11,  7,  3,  0],
#         ...,
#         [ 6,  7,  7,  7,  0],
#         [12, 15,  8,  1,  0],
#         [13, 13,  8, 13,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([4, 4, 4,  ..., 4, 4, 4])
# tensor([[12, 12,  8,  1,  0],
#         [ 1,  5,  3, 15,  0],
#         [11, 11,  7,  3,  0],
#         ...,
#         [ 6,  7,  7,  7,  0],
#         [12, 15,  8,  1,  0],
#         [13, 13,  8, 13,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [4.0, 4.0, 4.0, 4.0]
# tensor([[ 3,  8,  8,  4,  0],
#         [ 3,  8,  8,  4,  0],
#         [11, 14,  9, 14,  0],
#         ...,
#         [11, 14, 15, 15,  0],
#         [11, 14,  6, 14,  0],
#         [11,  7,  7,  3,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([4, 4, 4,  ..., 4, 4, 4])
# tensor([[ 3,  8,  8,  4,  0],
#         [ 3,  8,  8,  4,  0],
#         [11, 14,  9, 14,  0],
#         ...,
#         [11, 14, 15, 15,  0],
#         [11, 14,  6, 14,  0],
#         [11,  7,  7,  3,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [4.0, 4.0, 4.0, 4.0]
# tensor([[ 7, 10, 12,  2,  0],
#         [12,  3,  3, 10,  0],
#         [13, 13, 12, 12,  0],
#         ...,
#         [ 5,  7,  7,  2,  0],
#         [ 2, 12, 12, 12,  0],
#         [ 5, 12,  3,  3,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([4, 4, 4,  ..., 4, 4, 4])
# tensor([[ 7, 10, 12,  2,  0],
#         [12,  3,  3, 10,  0],
#         [13, 13, 12, 12,  0],
#         ...,
#         [ 5,  7,  7,  2,  0],
#         [ 2, 12, 12, 12,  0],
#         [ 5, 12,  3,  3,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [4.0, 4.0, 4.0, 4.0]
# tensor([[ 3,  3,  7, 13,  0],
#         [13, 13, 13, 10,  0],
#         [ 8,  8,  8, 12,  0],
#         ...,
#         [ 7,  1,  1, 11,  0],
#         [13,  4, 13,  4,  0],
#         [14,  1,  1, 11,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([4, 4, 4,  ..., 4, 4, 4])
# tensor([[ 3,  3,  7, 13,  0],
#         [13, 13, 13, 10,  0],
#         [ 8,  8,  8, 12,  0],
#         ...,
#         [ 7,  1,  1, 11,  0],
#         [13,  4, 13,  4,  0],
#         [14,  1,  1, 11,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [4.0, 4.0, 4.0, 4.0]
# tensor([[27, 17,  6, 11,  0],
#         [10,  4, 13,  1,  0],
#         [ 1, 17,  2, 25,  0],
#         ...,
#         [21,  4, 20, 15,  0],
#         [22,  6, 20, 15,  0],
#         [25,  9, 16,  7,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([4, 4, 4,  ..., 4, 4, 4])
# tensor([[27, 17,  6, 11,  0],
#         [10,  4, 13,  1,  0],
#         [ 1, 17,  2, 25,  0],
#         ...,
#         [21,  4, 20, 15,  0],
#         [22,  6, 20, 15,  0],
#         [25,  9, 16,  7,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [4.0, 4.0, 4.0, 4.0]
# tensor([[17, 20, 22, 20,  0],
#         [ 6,  5,  5, 17,  0],
#         [ 8,  7, 23, 12,  0],
#         ...,
#         [20,  1, 22,  5,  0],
#         [ 7, 17, 14, 18,  0],
#         [20, 11, 19, 18,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([4, 4, 4,  ..., 4, 4, 4])
# tensor([[17, 20, 22, 20,  0],
#         [ 6,  5,  5, 17,  0],
#         [ 8,  7, 23, 12,  0],
#         ...,
#         [20,  1, 22,  5,  0],
#         [ 7, 17, 14, 18,  0],
#         [20, 11, 19, 18,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [4.0, 4.0, 4.0, 4.0]
# tensor([[ 5, 13, 19, 16,  0],
#         [ 3,  3,  2,  2,  0],
#         [ 5,  6, 17,  1,  0],
#         ...,
#         [ 2, 10, 10, 24,  0],
#         [ 3,  8, 14,  2,  0],
#         [ 5, 13,  8,  9,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([4, 4, 4,  ..., 4, 4, 4])
# tensor([[ 5, 13, 19, 16,  0],
#         [ 3,  3,  2,  2,  0],
#         [ 5,  6, 17,  1,  0],
#         ...,
#         [ 2, 10, 10, 24,  0],
#         [ 3,  8, 14,  2,  0],
#         [ 5, 13,  8,  9,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [4.0, 4.0, 4.0, 4.0]
# tensor([[ 6, 16, 24, 21,  0],
#         [26, 26, 10,  9,  0],
#         [ 5, 17, 16, 26,  0],
#         ...,
#         [25, 20, 26, 16,  0],
#         [ 4,  3, 18, 18,  0],
#         [22,  2, 11, 19,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([4, 4, 4,  ..., 4, 4, 4])
# tensor([[ 6, 16, 24, 21,  0],
#         [26, 26, 10,  9,  0],
#         [ 5, 17, 16, 26,  0],
#         ...,
#         [25, 20, 26, 16,  0],
#         [ 4,  3, 18, 18,  0],
#         [22,  2, 11, 19,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [4.0, 4.0, 4.0, 4.0]
# tensor([[20, 10, 12,  9,  0],
#         [21,  9,  9,  5,  0],
#         [ 9,  6, 16, 14,  0],
#         ...,
#         [ 2, 19,  2, 18,  0],
#         [20, 26, 23,  4,  0],
#         [27,  5, 13,  2,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([4, 4, 4,  ..., 4, 4, 4])
# tensor([[20, 10, 12,  9,  0],
#         [21,  9,  9,  5,  0],
#         [ 9,  6, 16, 14,  0],
#         ...,
#         [ 2, 19,  2, 18,  0],
#         [20, 26, 23,  4,  0],
#         [27,  5, 13,  2,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [4.0, 4.0, 4.0, 4.0]
# tensor([[11,  7,  2,  4,  3,  0],
#         [ 7, 10,  8,  7, 11,  0],
#         [ 9,  9,  9,  9,  8,  0],
#         ...,
#         [10, 11,  8,  7,  9,  0],
#         [10,  9,  3, 11,  7,  0],
#         [10, 14,  4,  3, 12,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([5, 5, 5,  ..., 5, 5, 5])
# tensor([[11,  7,  2,  4,  3,  0],
#         [ 7, 10,  8,  7, 11,  0],
#         [ 9,  9,  9,  9,  8,  0],
#         ...,
#         [10, 11,  8,  7,  9,  0],
#         [10,  9,  3, 11,  7,  0],
#         [10, 14,  4,  3, 12,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [5.0, 5.0, 5.0, 5.0, 5.0]
# tensor([[13, 13, 12, 10, 11,  0],
#         [15,  7, 14,  5, 10,  0],
#         [ 5,  3,  7,  1,  7,  0],
#         ...,
#         [ 5,  6,  6,  4,  5,  0],
#         [15, 12,  8,  2, 14,  0],
#         [15,  8,  4,  4,  9,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([5, 5, 5,  ..., 5, 5, 5])
# tensor([[13, 13, 12, 10, 11,  0],
#         [15,  7, 14,  5, 10,  0],
#         [ 5,  3,  7,  1,  7,  0],
#         ...,
#         [ 5,  6,  6,  4,  5,  0],
#         [15, 12,  8,  2, 14,  0],
#         [15,  8,  4,  4,  9,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [5.0, 5.0, 5.0, 5.0, 5.0]
# tensor([[ 9,  7, 11, 11,  4,  0],
#         [ 1,  9,  5, 11, 12,  0],
#         [ 9,  9,  5, 10, 12,  0],
#         ...,
#         [ 1,  4, 14,  8,  3,  0],
#         [ 9,  4,  4,  5, 15,  0],
#         [ 1,  1, 15,  5, 10,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([5, 5, 5,  ..., 5, 5, 5])
# tensor([[ 9,  7, 11, 11,  4,  0],
#         [ 1,  9,  5, 11, 12,  0],
#         [ 9,  9,  5, 10, 12,  0],
#         ...,
#         [ 1,  4, 14,  8,  3,  0],
#         [ 9,  4,  4,  5, 15,  0],
#         [ 1,  1, 15,  5, 10,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [5.0, 5.0, 5.0, 5.0, 5.0]
# tensor([[ 7,  5,  8, 15, 15,  0],
#         [ 9,  1,  3,  9,  9,  0],
#         [ 4,  2,  3, 13,  3,  0],
#         ...,
#         [ 6,  3,  5,  6, 15,  0],
#         [ 7,  2, 10, 14, 10,  0],
#         [ 9,  6,  9,  1,  1,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([5, 5, 5,  ..., 5, 5, 5])
# tensor([[ 7,  5,  8, 15, 15,  0],
#         [ 9,  1,  3,  9,  9,  0],
#         [ 4,  2,  3, 13,  3,  0],
#         ...,
#         [ 6,  3,  5,  6, 15,  0],
#         [ 7,  2, 10, 14, 10,  0],
#         [ 9,  6,  9,  1,  1,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [5.0, 5.0, 5.0, 5.0, 5.0]
# tensor([[ 1,  6,  7,  7,  7,  0],
#         [ 1, 10,  9,  2,  6,  0],
#         [13,  1,  1,  2,  3,  0],
#         ...,
#         [ 3,  1,  9, 10,  9,  0],
#         [13,  1, 10,  2,  4,  0],
#         [13, 10,  8,  3,  8,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# message length tensor([5, 5, 5,  ..., 5, 5, 5])
# tensor([[ 1,  6,  7,  7,  7,  0],
#         [ 1, 10,  9,  2,  6,  0],
#         [13,  1,  1,  2,  3,  0],
#         ...,
#         [ 3,  1,  9, 10,  9,  0],
#         [13,  1, 10,  2,  4,  0],
#         [13, 10,  8,  3,  8,  0]])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# hierarchical [5.0, 5.0, 5.0, 5.0, 5.0]

# %% [markdown]
# ###  symbol redundancy

# %%
for d in range(len(datasets)):
    
    attributes = n_attributes[d]
    values = n_values[d]
    vs_factor = int(paths[d][-2])
    vocab_size = (n_values[d] + 1) * vs_factor + 1
    
    for run in range(5): 
        
        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/'
        #symbol_f = np.load(path_to_run + 'symbols_pernsame.npy')
        #path_to_interaction = (path_to_run + 'interactions/train/interactions_epoch' + str(n_epochs))
        path_to_interaction = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        interaction = torch.load(path_to_interaction)
        redundancy, MI = symbol_frequency(interaction, attributes, values, vocab_size)
        
        scores = {'symbol_redundancy': redundancy, 'MI_symbol-attribute_value': MI}
        
        pickle.dump(scores, open(path_to_run + 'symbol_redundancy.pkl', 'wb'))
# Out:
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information
# c:\Users\rvver\Documents\CodeThesis\emergent-abstractions\utils\analysis_from_interaction.py:446: RuntimeWarning: invalid value encountered in divide
#   return symbol_frequency / att_val_frequency, mutual_information

# %% [markdown]
# ###  compositionality scores: topsim, posdis, bosdis

# %%
# topsim
# although topsim values are stored throughout training if callbacks are verbose, we reevaluate the
# final topsim scores with more data points 

samples = 5000 # maybe shuffle from these because otherwise I just take the first 5,000 (which might not be the best)
for d, dataset in enumerate(datasets):
    
    dim = [n_values[d]]*n_attributes[d]
    
    for run in range(5):
        print("dataset", dataset, "run", run)
        
        topsim_final = {}
        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/'
        path_to_interaction_train = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        path_to_interaction_val = (path_to_run + 'interactions/validation/epoch_' + str(n_epochs) + '/interaction_gpu0')
        
        TOPSIM = TopographicSimilarityConceptLevel(dim, is_gumbel=True)
        
        for mode in ['train', 'val']:

            if mode == 'train':
                interaction = torch.load(path_to_interaction_train)
            elif mode == 'val':
                interaction = torch.load(path_to_interaction_val)
                
                  
            messages = interaction.message.argmax(dim=-1)
            sender_input = interaction.sender_input
            n_targets = int(sender_input.shape[1]/2)
            # get target objects and fixed vectors to re-construct concepts
            target_objects = sender_input[:, :n_targets]
            target_objects = k_hot_to_attributes(target_objects, n_values[d])
            # concepts are defined by a list of target objects (here one sampled target object) and a fixed vector
            (objects, fixed) = retrieve_concepts_sampling(target_objects)
            # add one such that zero becomes an empty attribute for the calculation (_)
            objects = objects + 1
            concepts = torch.from_numpy(objects * (np.array(fixed)))
            specific_idx = np.where(np.sum(fixed, axis=1)==n_attributes[d])[0]
            messages_specific = messages[specific_idx]
            concepts_specific = concepts[specific_idx]
            
            generic_idx = np.where(np.sum(fixed, axis=1)==1)[0]
            messages_generic = messages[generic_idx]
            concepts_generic = concepts[generic_idx]

            messages = [msg.tolist() for msg in messages]
            messages_specific = [msg.tolist() for msg in messages_specific]
            messages_generic = [msg.tolist() for msg in messages_generic]

            encoded_input = encode_target_concepts_for_topsim(sender_input)
            # randomly take samples when more than 5000 samples are available
            # if len(encoded_input) > samples: 
            #     print("sampling")
            #     sample_indices = random.sample(range(len(encoded_input)), samples)
            #     sampled_input = [encoded_input[i] for i in sample_indices]
            #     sampled_messages = [messages[i] for i in sample_indices]
            #     print("start computing")
            #     print(len(sampled_input), len(sampled_input[0]), len(sampled_input[0][0]))
            #     topsim = TOPSIM.compute_topsim(sampled_input, sampled_messages)
            # else:
            topsim = TOPSIM.compute_topsim(encoded_input[0:samples], messages[0:samples]) # default: hausdorff distance for concepts, edit distance for messages
            # if len(concepts_specific) > samples:
            #     print("sampling specific")
            #     sample_indices_specific = random.sample(range(len(concepts_specific)), samples)
            #     sampled_input_specific = [concepts_specific[i] for i in sample_indices_specific]
            #     sampled_messages_specific = [messages_specific[i] for i in sample_indices_specific]
            #     topsim_specific = TOPSIM.compute_topsim(sampled_input_specific, sampled_messages_specific, 
            #                                             meaning_distance_fn="edit")
            # else:
            topsim_specific = TOPSIM.compute_topsim(concepts_specific[0:samples], messages_specific[0:samples], 
                                                        meaning_distance_fn="edit")
            
            topsim_generic = TOPSIM.compute_topsim(concepts_generic[0:samples], messages_generic[0:samples],
                                                   meaning_distance_fn="edit")

            print('... topsim computed')

            topsim_final['topsim_' + mode] = topsim
            topsim_final['topsim_specific_' + mode] = topsim_specific
            topsim_final['topsim_generic_' + mode] = topsim_generic
    
        pickle.dump(topsim_final, open(path_to_run +  "topsim_final.pkl", "wb" ) )
        print(topsim_final)
# Out:
# dataset (3,4) run 0
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.36673939618651313, 'topsim_specific_train': 0.42714863625408206, 'topsim_generic_train': 0.27275631999493327, 'topsim_val': 0.358522625674759, 'topsim_specific_val': 0.4195625671961671, 'topsim_generic_val': 0.3777552460887769}
# dataset (3,4) run 1
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.3432315381081097, 'topsim_specific_train': 0.43632975678902935, 'topsim_generic_train': 0.3110145829282194, 'topsim_val': 0.35477653205096116, 'topsim_specific_val': 0.45256387434648165, 'topsim_generic_val': 0.38129642757119775}
# dataset (3,4) run 2
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.36500185193180124, 'topsim_specific_train': 0.39876461545670394, 'topsim_generic_train': 0.3561847590476301, 'topsim_val': 0.3753263298570539, 'topsim_specific_val': 0.4209089963095822, 'topsim_generic_val': 0.2920285129898371}
# dataset (3,4) run 3
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.4416827269810719, 'topsim_specific_train': 0.4123892683510355, 'topsim_generic_train': 0.2941273187191504, 'topsim_val': 0.43415997097678544, 'topsim_specific_val': 0.4340542295610974, 'topsim_generic_val': 0.32586700507043337}
# dataset (3,4) run 4
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.41788382988150213, 'topsim_specific_train': 0.4342627323228647, 'topsim_generic_train': 0.3217345930076865, 'topsim_val': 0.40557544601873796, 'topsim_specific_val': 0.40303071646885585, 'topsim_generic_val': 0.3298768925762433}
# dataset (3,8) run 0
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.045626992152178095, 'topsim_specific_train': 0.22531887816787238, 'topsim_generic_train': 0.10937149200127927, 'topsim_val': 0.043149251310660594, 'topsim_specific_val': 0.22647326270808707, 'topsim_generic_val': 0.19404003220473667}
# dataset (3,8) run 1
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.2216315257267436, 'topsim_specific_train': 0.255419808840804, 'topsim_generic_train': 0.21801109428377385, 'topsim_val': 0.22437230451311008, 'topsim_specific_val': 0.2560907876724124, 'topsim_generic_val': 0.12848449214993185}
# dataset (3,8) run 2
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.1454620771691693, 'topsim_specific_train': 0.2513604379571552, 'topsim_generic_train': 0.30003857598153394, 'topsim_val': 0.14787231909318568, 'topsim_specific_val': 0.2506246771861845, 'topsim_generic_val': 0.2691003252840698}
# dataset (3,8) run 3
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.12211738206162333, 'topsim_specific_train': 0.25966731576112245, 'topsim_generic_train': 0.4800792486948424, 'topsim_val': 0.11693264859428813, 'topsim_specific_val': 0.2613574773144129, 'topsim_generic_val': 0.3661577867064827}
# dataset (3,8) run 4
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.23665360923067683, 'topsim_specific_train': 0.3139956140813384, 'topsim_generic_train': 0.41779891000647684, 'topsim_val': 0.2442333530511841, 'topsim_specific_val': 0.31532283254413607, 'topsim_generic_val': 0.3273055908232259}
# dataset (3,16) run 0
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.2128893022701579, 'topsim_specific_train': 0.15645979842080002, 'topsim_generic_train': 0.07325453579015521, 'topsim_val': 0.2202433615522419, 'topsim_specific_val': 0.1518963258809809, 'topsim_generic_val': 0.050478101033231075}
# dataset (3,16) run 1
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.12491480709183739, 'topsim_specific_train': 0.16397037159589598, 'topsim_generic_train': 0.13720166991361288, 'topsim_val': 0.13513516336287873, 'topsim_specific_val': 0.16217999362441143, 'topsim_generic_val': 0.06323651110307113}
# dataset (3,16) run 2
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.09488844069060572, 'topsim_specific_train': 0.12685217542019875, 'topsim_generic_train': 0.08365602184655761, 'topsim_val': 0.09113726942804355, 'topsim_specific_val': 0.1315216834561625, 'topsim_generic_val': 0.09070319554031714}
# dataset (3,16) run 3
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.18994403200887922, 'topsim_specific_train': 0.1782484730683853, 'topsim_generic_train': 0.1729013300378412, 'topsim_val': 0.19427965954851426, 'topsim_specific_val': 0.18546385769703605, 'topsim_generic_val': 0.09721315550200149}
# dataset (3,16) run 4
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.1144604464671834, 'topsim_specific_train': 0.19531369700075, 'topsim_generic_train': 0.3202949787426593, 'topsim_val': 0.11396744090409358, 'topsim_specific_val': 0.1910267211274375, 'topsim_generic_val': 0.38869780392582565}
# dataset (4,4) run 0
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.23844149862441372, 'topsim_specific_train': 0.3136640556205152, 'topsim_generic_train': 0.32831482046011023, 'topsim_val': 0.23446601591703362, 'topsim_specific_val': 0.31785545551499805, 'topsim_generic_val': 0.17563149484817003}
# dataset (4,4) run 1
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.36849747857389975, 'topsim_specific_train': 0.36909713342893563, 'topsim_generic_train': 0.22965985922595217, 'topsim_val': 0.37745893981905165, 'topsim_specific_val': 0.3744448359522498, 'topsim_generic_val': 0.2355419091343867}
# dataset (4,4) run 2
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.1944174559863815, 'topsim_specific_train': 0.26012949194666946, 'topsim_generic_train': 0.2600833850724056, 'topsim_val': 0.18744154075509947, 'topsim_specific_val': 0.27091904759868085, 'topsim_generic_val': 0.17955614252914223}
# dataset (4,4) run 3
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.33131080998684853, 'topsim_specific_train': 0.31836595598744216, 'topsim_generic_train': 0.3467928853890347, 'topsim_val': 0.33243685912061793, 'topsim_specific_val': 0.32466804440246116, 'topsim_generic_val': 0.44943217520044276}
# dataset (4,4) run 4
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.35599362269954554, 'topsim_specific_train': 0.29105867349916037, 'topsim_generic_train': 0.27089242286222415, 'topsim_val': 0.35397491061982667, 'topsim_specific_val': 0.2830912611021445, 'topsim_generic_val': 0.3530247055075245}
# dataset (4,8) run 0
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.20686863311215858, 'topsim_specific_train': 0.2622473230298342, 'topsim_generic_train': 0.241086274157945, 'topsim_val': 0.20193558910733742, 'topsim_specific_val': 0.2597158263127565, 'topsim_generic_val': 0.24438940548699714}
# dataset (4,8) run 1
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.1927870582737256, 'topsim_specific_train': 0.3715853673461916, 'topsim_generic_train': 0.41239841915522785, 'topsim_val': 0.19755417475729573, 'topsim_specific_val': 0.37895191280839485, 'topsim_generic_val': 0.42246324730036844}
# dataset (4,8) run 2
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.2480619169388864, 'topsim_specific_train': 0.2132502788441253, 'topsim_generic_train': 0.18202410773690195, 'topsim_val': 0.2562968654583069, 'topsim_specific_val': 0.21907217707821577, 'topsim_generic_val': 0.14372689031088012}
# dataset (4,8) run 3
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.16633921314201194, 'topsim_specific_train': 0.20752741927676482, 'topsim_generic_train': 0.1682741047187442, 'topsim_val': 0.18910484999277882, 'topsim_specific_val': 0.2106422820174599, 'topsim_generic_val': 0.16842443480211436}
# dataset (4,8) run 4
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.24290735715820386, 'topsim_specific_train': 0.28356396786695975, 'topsim_generic_train': 0.09563084899251707, 'topsim_val': 0.24993303425112479, 'topsim_specific_val': 0.28472056039828064, 'topsim_generic_val': 0.07630270730338215}
# dataset (5,4) run 0
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.29586646959521923, 'topsim_specific_train': 0.3707135562427176, 'topsim_generic_train': 0.40766032852428086, 'topsim_val': 0.29610719046227985, 'topsim_specific_val': 0.369795101600625, 'topsim_generic_val': 0.3916314746245938}
# dataset (5,4) run 1
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.24071950070056128, 'topsim_specific_train': 0.34942057537092336, 'topsim_generic_train': 0.29482301312275055, 'topsim_val': 0.2392953339240701, 'topsim_specific_val': 0.3512453823532631, 'topsim_generic_val': 0.21944817366718275}
# dataset (5,4) run 2
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.27491848599636526, 'topsim_specific_train': 0.2791455611736014, 'topsim_generic_train': 0.19145051452227924, 'topsim_val': 0.28059267964900136, 'topsim_specific_val': 0.28640148467312493, 'topsim_generic_val': 0.1267565695007875}
# dataset (5,4) run 3
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.27034003598314715, 'topsim_specific_train': 0.32782175639542566, 'topsim_generic_train': 0.39422796403030064, 'topsim_val': 0.26453804974956624, 'topsim_specific_val': 0.3336946885939154, 'topsim_generic_val': 0.34425966185210427}
# dataset (5,4) run 4
# ... topsim computed
# ... topsim computed
# {'topsim_train': 0.28901533195549395, 'topsim_specific_train': 0.2832699531478701, 'topsim_generic_train': 0.17525860159969212, 'topsim_val': 0.295788189034819, 'topsim_specific_val': 0.2883401209727996, 'topsim_generic_val': 0.19168844221179668}

# %%
# use Disent callback from egg

for d in range(len(datasets)): 
    
    path = paths[d]
    dim = [n_values[d]] * n_attributes[d]
    n_features = n_attributes[d] * n_values[d]
    vs_factor = int(path[-2])
    vocab_size = (n_values[d] + 1) * vs_factor + 1
    
    print("data set", dim)
    
    for run in range(5):
        
        posdis_bosdis = {}
    
        path_to_run = paths[d] + '/' + str(setting) +'/' + str(run) + '/'
        path_to_interaction_train = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        interaction = torch.load(path_to_interaction_train)
        
        messages = interaction.message.argmax(dim=-1)
        sender_input = interaction.sender_input
        n_targets = int(sender_input.shape[1]/2)
        # get target objects and fixed vectors to re-construct concepts
        target_objects = sender_input[:, :n_targets]
        target_objects = k_hot_to_attributes(target_objects, n_values[d])
        # concepts are defined by a list of target objects (here one sampled target object) and a fixed vector
        (objects, fixed) = retrieve_concepts_sampling(target_objects)
        # add one such that zero becomes an empty attribute for the calculation (_)
        objects = objects + 1
        concepts = torch.from_numpy(objects * (np.array(fixed)))

        # concrete/specific concepts: where all attributes are fixed
        concepts_specific = torch.tensor(
            objects[torch.sum(torch.from_numpy(fixed), dim=1) == n_attributes[d]])
        messages_specific = messages[torch.sum(torch.from_numpy(fixed), dim=1) == n_attributes[d]]

        # generic concepts: where only one attribute is fixed
        concepts_generic = torch.tensor(
            objects[torch.sum(torch.from_numpy(fixed), dim=1) == 1])
        messages_generic = messages[torch.sum(torch.from_numpy(fixed), dim=1) == 1]
        
        posdis_specific = Disent.posdis(concepts_specific, messages_specific)
        bosdis_specific = Disent.bosdis(concepts_specific, messages_specific, vocab_size)

        posdis_generic = Disent.posdis(concepts_generic, messages_generic)
        bosdis_generic = Disent.bosdis(concepts_generic, messages_generic, vocab_size)
        
        posdis = Disent.posdis(torch.from_numpy(objects), messages)
        bosdis = Disent.bosdis(torch.from_numpy(objects), messages, vocab_size)
        
        posdis_bosdis['posdis_specific'] = posdis_specific
        posdis_bosdis['bosdis_specific'] = bosdis_specific
        posdis_bosdis['posdis_generic'] = posdis_generic
        posdis_bosdis['bosdis_generic'] = bosdis_generic
        posdis_bosdis['posdis'] = posdis
        posdis_bosdis['bosdis'] = bosdis

        print(posdis_bosdis)
    
        pickle.dump(posdis_bosdis, open(path_to_run + "posdis_bosdis.pkl", "wb" ) )

# %%
# bosdis concept x context
for d in range(len(datasets)):

    vs_factor = int(paths[d][-2])
    vocab_size = (n_values[d] + 1) * vs_factor + 1
    
    for run in range(5):

        path_to_run = paths[d] + '/' + str(setting) +'/' + str(run) + '/' 
        path_to_interaction = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        interaction = torch.load(path_to_interaction)

        attributes = n_attributes[d]
        values = n_values[d]
        scores = bosdis(interaction, attributes, values, vocab_size)

        pickle.dump(scores, open(path_to_run + 'bosdis_scores.pkl', 'wb'))

# %%
# posdis concept x context
for d in range(len(datasets)):

    vs_factor = int(paths[d][-2])
    vocab_size = (n_values[d] + 1) * vs_factor + 1

    for run in range(5):
        path_to_run = paths[d] + '/' + str(setting) + '/' + str(run) + '/'
        print(path_to_run)
        path_to_interaction = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        #print(path_to_interaction)
        interaction = torch.load(path_to_interaction)

        attributes = n_attributes[d]
        values = n_values[d]
        scores = posdis(interaction, attributes, values, vocab_size)

        pickle.dump(scores, open(path_to_run + 'posdis_scores.pkl', 'wb'))
# Out:
# results/vague_ds_results/(3,4)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(3,4)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(3,4)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(3,4)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(3,4)_game_size_10_vsf_3//standard/4/
# results/vague_ds_results/(3,8)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(3,8)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(3,8)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(3,8)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(3,8)_game_size_10_vsf_3//standard/4/
# results/vague_ds_results/(3,16)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(3,16)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(3,16)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(3,16)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(3,16)_game_size_10_vsf_3//standard/4/
# results/vague_ds_results/(4,4)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(4,4)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(4,4)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(4,4)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(4,4)_game_size_10_vsf_3//standard/4/
# results/vague_ds_results/(4,8)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(4,8)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(4,8)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(4,8)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(4,8)_game_size_10_vsf_3//standard/4/
# results/vague_ds_results/(5,4)_game_size_10_vsf_3//standard/0/
# results/vague_ds_results/(5,4)_game_size_10_vsf_3//standard/1/
# results/vague_ds_results/(5,4)_game_size_10_vsf_3//standard/2/
# results/vague_ds_results/(5,4)_game_size_10_vsf_3//standard/3/
# results/vague_ds_results/(5,4)_game_size_10_vsf_3//standard/4/

# %% [markdown]
# ### co-occurrences

# %%
# Not yet implemented:

for d in range(len(datasets)):
    
    vs_factor = int(paths[d][-2])
    
    for run in range(5): 
        
        path_to_run = paths[d] + str(setting) +'/' + str(run) + '/'
        path_to_interaction = (path_to_run + 'interactions/train/epoch_' + str(n_epochs) + '/interaction_gpu0')
        interaction = torch.load(path_to_interaction)

        attributes = n_attributes[d]
        values = n_values[d]
        
        scores = cooccurrence_per_hierarchy_level(interaction, attributes, values, vs_factor)

        print(scores)
        
        pickle.dump(scores, open(path_to_run + 'normalized_cooccurrence.pkl', 'wb'))
